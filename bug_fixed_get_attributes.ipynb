# %%
def get_lawyer(ls):

    num  = len(ls)

    #因為律師可能不只一個所以塞進list裡面
    Plaintiffs_lawyer = []
    Defendants_lawyer = []
    for i in range(0,num):
        ls[i] = ls[i].replace(u'　',u'').replace(u' ',u'')
        #find Plaintiff 's lawyer
        if ls[i].find(u'原告') != -1:
            for terminal in range(1,20):
                next_line = ls[i+terminal].replace(u'　',u'').replace(u' ',u'')
                if next_line.find(u'被告') != -1:
                    break
                if next_line.find(u'律師') != -1:
                    if len(next_line)>5:
                        if u'複代理人' in next_line:
                            next_line = next_line.split(u'複代理人')[1]
                            people = next_line.find(u'律師')
                            Plaintiffs_lawyer.append(next_line[:people+2])
                            continue
                            
                        elif len(next_line)>10:
                            people = next_line.find(u'人')
                            law = next_line.find(u'律師')
                            Plaintiffs_lawyer.append(next_line[people+1:law+2])
                            continue
                            
                        elif u'共同訴訟代' in next_line:
                            cor = next_line.find(u'共同')
                            Plaintiffs_lawyer.append(next_line[cor+5:])
                            continue
                        
                        elif u'共同' in next_line and u'訴訟代' not in next_line:
                            cor = next_line.find(u'共同')
                            Plaintiffs_lawyer.append(next_line[cor+2:])
                            continue
                            
                        else:
                            people = next_line.find(u'人')
                            Plaintiffs_lawyer.append(next_line[people+1:])
                    else:
                        Plaintiffs_lawyer.append(next_line)


        #find Defendant 's lawyer
        if u'被告' in ls[i]:
            
            for terminal in range(1,20):
                next_line = ls[i+terminal].replace(u'　',u'').replace(u' ',u'')
                if u'主文' in next_line:
                    break
                    
                if u'律師' in next_line:
                    if len(next_line)>5:
                        if u'複代理人' in next_line:
                            next_line = next_line.split(u'複代理人')[1]
                            people = next_line.find(u'律師')
                            Defendants_lawyer.append(next_line[:people+2])
                            continue
                            
                        elif len(next_line)>10:
                            people = next_line.find(u'人')
                            law = next_line.find(u'律師')
                            Defendants_lawyer.append(next_line[people+1:law+2])
                            continue
                            
                        elif u'共同訴訟代' in next_line:
                            cor = next_line.find(u'共同')
                            Defendants_lawyer.append(next_line[cor+5:])
                            continue
                        
                        elif u'共同' in next_line and u'訴訟代' not in next_line:
                            cor = next_line.find(u'共同')
                            Defendants_lawyer.append(next_line[cor+2:])
                            continue

                        else:
                            people = next_line.find(u'人')
                            Defendants_lawyer.append(next_line[people+1:])
                    else:
                        Defendants_lawyer.append(next_line)
            break
    
#     for i in Plaintiffs_lawyer:
#         print len(i),i
#     print '---'
#     for i in Defendants_lawyer:
#         print len(i),i
    Plaintiffs_lawyer = Plaintiffs_lawyer if len(Plaintiffs_lawyer) != 0 else 0
    Defendants_lawyer = Defendants_lawyer if len(Defendants_lawyer) != 0 else 0
    return Plaintiffs_lawyer , Defendants_lawyer
    

print 'def get_lawyer(ls) set'
# Out:
# def get_lawyer(ls) set

# %%
def Plaintiff_win(ls):
    for i in range(len(ls)):
        line = ls[i].replace(u'　',u'').replace(u' ',u'').strip()
        if u'主文' in line:
            start = i
        if u'事實' in line or u'理由' in line:
            stop = i
            break
#     print '\n'.join(ls[start:stop])
    if u'給付' in '\n'.join(ls[start:stop]):
        return True
    else:
        return False        

print 'def Plaintiff_win(ls) set'
# Out:
# def Plaintiff_win(ls) set

# %%
def get_judgement_type(ls):
    for line in ls:
        if u'地方法院' in line:
            if u'簡易庭' in line:
                start_pos = line.find(u'簡易庭')
                judgement_type = line.split(u'　')[0][start_pos+3:].encode('utf-8')
                return judgement_type.decode('utf-8')
                break    
            start_pos = line.find(u'地方法院')
            judgement_type = line.split(u'　')[0][start_pos+4:].encode('utf-8')
            return judgement_type.decode('utf-8')
            break
print 'def get_judgement_type(ls) set'
# Out:
# def get_judgement_type(ls) set

# %%
#方法 transform-----輸入 money
def transform(money):
    num=0      #for 中文數字的第幾個位置
    total = 0  #for 數字總合
    #------------
    get_m = [] #塞入money_unit

    get_n = [] #塞入number
    #------------
#     simple_money_unit ={u'萬':10000,u'千':1000,u'百':100,u'十':10}
#     simple_number={u'零':0,u'一':1,u'二':2,u'三':3,u'四':4,\
#                    u'五':5,u'六':6,u'七':7,u'八':8,u'九':9}
#     money_unit ={u'萬':10000,u'仟':1000,u'佰':100,u'拾':10}
#     number={u'零':0,u'壹':1,u'貳':2,u'參':3,u'肆':4,\
#             u'伍':5,u'陸':6,u'柒':7,u'捌':8,u'玖':9}
#     #------------
#     #判斷是否為大寫數字 還小寫
#     if money[0] in simple_number or money[0] in simple_money_unit:
#         money_unit = simple_money_unit
#         number = simple_number
# #     print money #印出中文大寫數字
#     #------------

    
    money_unit ={u'萬':10000,u'仟':1000,u'佰':100,u'拾':10,u'千':1000,u'百':100,u'十':10}
    number={u'零':0,u'壹':1,u'貳':2,u'參':3,u'肆':4,\
            u'伍':5,u'陸':6,u'柒':7,u'捌':8,u'玖':9,\
            u'一':1,u'二':2,u'三':3,u'四':4,\
            u'五':5,u'六':6,u'七':7,u'八':8,u'九':9}
    
    
    for x in range(0,len(money)):
        if money[num]==u'零':#若是0就跳過
            num+=1
            continue
        elif money[num] in number:#若是 數字 開頭
            if num==len(money)-1:#判斷是否目前位置等於總長度    相等 是有個位數
                get_n.append(number[money[num]])
                get_m.append(1)
                break

            get_n.append(number[money[num]])
            num+=1

            get_m.append(money_unit[money[num]])

            if num==len(money)-1:#若是沒有個位數 就直接結束
                break
            num+=1

            if money[num] in money_unit:#只看是否是 萬  eg  壹拾萬  拾萬
                get_n.append(0)
                get_m.append(money_unit[money[num]])
                if num==len(money)-1:
                    break
                num+=1

                if num==len(money)-1:#若是沒有個位數 就直接結束
                    break

        elif money[num] in money_unit:#若是 十 開頭  eg  拾萬
            get_n.append(1)
            get_m.append(10)
            num+=1
            get_n.append(0)
            get_m.append(money_unit[money[num]])
            
            
            if num==len(money)-1:
                break
                
            num+=1
            
            if money[num] in money_unit:
                #print num,0,money_unit[money[num]],'shit'

                get_n.append(0)
                get_m.append(money_unit[money[num]])
                num+=1

                if num==len(money)-1:
                    break

    #運用get_n get_m 倆倆一組 開始相乘
    times = len(get_n) if get_n>get_m else len(get_m)
    
    if 10000 in get_m:                 #若是有 "萬"
        change = get_m.index(10000)    #找出萬的位置
        for x in range(0,change):      #萬以前的單位 get_m 都乘 10000
            get_m[x] = get_m[x]*10000

    for x in range(0,times):           #get_m * get_n 在相加到 total
        total+=get_n[x]*get_m[x]
    
    return total
#     print '判賠金額 - %d'%total
print 'def transform(ls) set'
# Out:
# def transform(ls) set

# %%
def get_money(ls):
    for i in range(len(ls)):
        ls[i] = ls[i].replace(u'　',u'').replace(u' ',u'').strip()
        if u'主文' in ls[i]:
            start = i
        if u'事實' in ls[i] or u'理由' in ls[i]:
            stop = i
            break
            
    content = u''.join(ls[start:stop]).replace(u',','')
#     print content
    if u'給付' in content:
        dollars = content.find(u'元')
#         big_nt = content.find(u'新臺幣') if u'新臺幣' in content else 0
#         simple_nt = content.find(u'新台幣') if u'新台幣' in content else 0
#         nt = big_nt if big_nt < simple_nt and big_nt != 0 else simple_nt
        nt = content.find(u'幣')
        money = content[nt+1:dollars]
#         print money
        try:
            return int(money)
        except:
            total = transform(money)
            return total
    else:
        return 0
    
print 'def get_money(ls) set'

# location = u'project\\verdict\\'
# all_files = os.path.abspath(location)
# for x in os.listdir(all_files)[30:100]:
#     place = x.split(u'_')[0]
#     dic[u'地點'] = place
#     dic[u'判決名稱'] = x.split('.')[0]
#     with codecs.open(os.path.join(location,x),'r','utf-8') as f:
#         ls = []
#         for line in f:
#             if line.strip() != 0:
#                 ls.append(line)
#     print x
#     get_money(ls)
#     print '-------------'
# Out:
# def get_money(ls) set

# %%
import os.path
import codecs
dic = {
    u'地點':'',
    u'判決名稱':'',
    u'判決種類':'',
    u'判決金額':'',
    u'原告勝訴':'',
    u'律師':''
}
location = u'project\\verdict\\'
all_files = os.path.abspath(location)
for x in os.listdir(all_files)[1000:1500]:
    place = x.split(u'_')[0]
    dic[u'地點'] = place
    dic[u'判決名稱'] = x.split('.')[0]
    with codecs.open(os.path.join(location,x),'r','utf-8') as f:
        ls = []
        for line in f:
            if line.strip() != 0:
                ls.append(line)
    dic[u'原告勝訴'] = Plaintiff_win(ls)
    dic[u'判決種類'] = get_judgement_type(ls)
    dic[u'律師']=list(get_lawyer(ls))
    dic[u'判決金額'] = get_money(ls)
    
    for x in dic:
        print '%s\t%s'%(x,dic[x])
    print '---------------------------'
# Out:
# 律師	[0, 0]
# 地點	臺中
# 判決金額	80000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1267
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u5049\u5c55\u5f8b\u5e2b', u'\u66fe\u5a49\u9234\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	200000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1296
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	20000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1301
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u6d69\u83ef\u5f8b\u5e2b'], [u'\u9f94\u6b63\u6587\u5f8b\u5e2b', u'\u9673\u5b8f\u76c8\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_1316
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	1600890
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1338
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9ec3\u9756\u9594\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	50000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1348
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u6d2a\u660e\u7acb\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	462776
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1353
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	50000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1356
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	200000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_1359
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u91d1\u6751\u5f8b\u5e2b\r'], [u'\u6797\u898b\u8ecd\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5b6b\u660e\u7199\u5f8b\u5e2b'], [u'\u6d2a\u5d07\u6b3d\u5f8b\u5e2b', u'\u5f90\u66c9\u840d\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	405000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_3367
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u8521\u5949\u5178\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	5078160
# 原告勝訴	True
# 判決名稱	臺中_101_訴_337
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	1055000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_345
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	400000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_368
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	232590
# 原告勝訴	True
# 判決名稱	臺中_101_訴_38
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u65bd\u5ef7\u52f3\u5f8b\u5e2b'], [u'\u5442\u52dd\u8ce2\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_380
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	176837
# 原告勝訴	True
# 判決名稱	臺中_101_訴_390
# 判決種類	民事判決
# ---------------------------
# 律師	[0, [u'\u90ed\u9686\u5049\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	77115
# 原告勝訴	True
# 判決名稱	臺中_101_訴_391
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u859b\u4efb\u667a\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	100000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_425
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	142674
# 原告勝訴	True
# 判決名稱	臺中_101_訴_428
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	154685
# 原告勝訴	True
# 判決名稱	臺中_101_訴_433
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u738b\u570b\u6cf0\u5f8b\u5e2b', u'\u6d2a\u745e\u9719\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	233092
# 原告勝訴	True
# 判決名稱	臺中_101_訴_438
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	400000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_458
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u6021\u73ca\u5f8b\u5e2b', u'\u90ed\u4e43\u7469\u5f8b\u5e2b'], [u'\u694a\u96ef\u9f61\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	225928
# 原告勝訴	True
# 判決名稱	臺中_101_訴_463
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u66fe\u528d\u8679\u5f8b\u5e2b'], [u'\u66fe\u6e05\u5c71\u5f8b\u5e2b\r']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_473
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	320828
# 原告勝訴	True
# 判決名稱	臺中_101_訴_477
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5289\u7469\u73b2\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_479
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u738b\u570b\u6cf0\u5f8b\u5e2b', u'\u6d2a\u745e\u9719\u5f8b\u5e2b'], [u'\u6c5f\u4f86\u76db\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	1180116
# 原告勝訴	True
# 判決名稱	臺中_101_訴_518
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u66fe\u6176\u5d07\u5f8b\u5e2b', u'\u738b\u5fb7\u51f1\u5f8b\u5e2b'], [u'\u9ad8\u9032\u68d6\u5f8b\u5e2b', u'\u8607\u986f\u9a30\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	911642
# 原告勝訴	True
# 判決名稱	臺中_101_訴_546
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	100000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_548
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5f35\u96ef\u5cf0\u5f8b\u5e2b'], [u'\u9ad8\u9032\u68d6\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	552008
# 原告勝訴	True
# 判決名稱	臺中_101_訴_549
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u8a31\u8212\u51f1\u5f8b\u5e2b'], [u'\u9673\u7531\u9293\u5f8b\u5e2b\r']]
# 地點	臺中
# 判決金額	820206
# 原告勝訴	True
# 判決名稱	臺中_101_訴_582
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u738b\u7d20\u73b2\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	560000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_599
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_620
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u6e05\u83ef\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	1033475
# 原告勝訴	True
# 判決名稱	臺中_101_訴_658
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u6851\u9298\u5fe0\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	1685625
# 原告勝訴	True
# 判決名稱	臺中_101_訴_693
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	472777
# 原告勝訴	True
# 判決名稱	臺中_101_訴_694
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	250000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_73
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_741
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	491801
# 原告勝訴	True
# 判決名稱	臺中_101_訴_744
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5b8b\u6c38\u7965\u5f8b\u5e2b', u'\u6d2a\u7ff0\u4eca\u5f8b\u5e2b'], [u'\u8a31\u6f22\u9130\u5f8b\u5e2b', u'\u8a31\u5bb6\u745c\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	2519399
# 原告勝訴	True
# 判決名稱	臺中_101_訴_745
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	608185
# 原告勝訴	True
# 判決名稱	臺中_101_訴_851
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u6797\u677e\u864e\u5f8b\u5e2b', u'\u6797\u660e\u6bc5\u5f8b\u5e2b\r'], 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_857
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u80b2\u4ec1\u5f8b\u5e2b', u'\u4f55\u570b\u69ae\u5f8b\u5e2b'], [u'\u9673\u5927\u4fca\u5f8b\u5e2b', u'\u5f35\u79c0\u745c\u5f8b\u5e2b\r']]
# 地點	臺中
# 判決金額	85800
# 原告勝訴	True
# 判決名稱	臺中_101_訴_888
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	532945
# 原告勝訴	True
# 判決名稱	臺中_101_訴_897
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u6d69\u83ef\u5f8b\u5e2b', u'\u9673\u6d69\u83ef\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	215533
# 原告勝訴	True
# 判決名稱	臺中_101_訴_898
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_910
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u838a\u6176\u6d32\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	1500000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_942
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5468\u555f\u540c\u5f8b\u5e2b', u'\u5468\u555f\u540c\u5f8b\u5e2b'], [u'\u6e38\u7426\u4fca\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_訴_957
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u65bd\u745e\u7ae0\u5f8b\u5e2b'], [u'\u9ec3\u5e7c\u862d\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	400000
# 原告勝訴	True
# 判決名稱	臺中_101_訴_978
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	736125
# 原告勝訴	True
# 判決名稱	臺中_101_訴_980
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	592440
# 原告勝訴	True
# 判決名稱	臺中_101_訴_990
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	8150
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_101
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	4456
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_190
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	43250
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_241
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	7065
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_27
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_豐小_278
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	30000
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_31
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	39750
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_317
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	2774
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_332
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	20980
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_355
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	39099
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_357
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	10760
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_405
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	14377
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_411
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	41510
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_427
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	32780
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_429
# 判決種類	小額民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	74990
# 原告勝訴	True
# 判決名稱	臺中_101_豐小_467
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	157608
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_1
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	100740
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_131
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	286521
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_141
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	70243
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_156
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	73893
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_159
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	89200
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_170
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	41100
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_171
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	12992
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_181
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u4f55\u5fd7\u63da\u5f8b\u5e2b', u'\u694a\u5b87\u5022\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	263674
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_188
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	108542
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_190
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	216328
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_2
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	221635
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_254
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	140000
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_256
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	328634
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_261
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5eb7\u5b58\u5b5d\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_豐簡_271
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	152019
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_286
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	168041
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_365
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	132179
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_387
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_豐簡_404
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	456550
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_416
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	50000
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_419
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	109876
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_473
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	11634
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_5
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	27960
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_519
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_豐簡_526
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	152083
# 原告勝訴	True
# 判決名稱	臺中_101_豐簡_79
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u5bb6\u9a4a\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_10
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u60e0\u4f36\u5f8b\u5e2b', u'\u738b\u79cb\u971c\u5f8b\u5e2b'], [u'\u674e\u6176\u677e\u5f8b\u5e2b', u'\u8cf4\u601d\u9054\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_14
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u718a\u8ce2\u5b89\u5f8b\u5e2b'], [u'\u8521\u632f\u4fee\u5f8b\u5e2b', u'\u80e1\u90c1\u4f36\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_22
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u738b\u8000\u8ce2\u5f8b\u5e2b', u'\u8b1d\u52dd\u9686\u5f8b\u5e2b'], [u'\u5ed6\u5fd7\u582f\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_27
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u694a\u96ef\u9f61\u5f8b\u5e2b', u'\u7f85\u570b\u658c\u5f8b\u5e2b'], [u'\u738b\u4e00\u7ff0\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_29
# 判決種類	民事判決
# ---------------------------
# 律師	[0, [u'\u738b\u5fb7\u51f1\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_醫_8
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u
u5f8b\u5e2b\r']]
# 地點	臺中
# 判決金額	534239
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_307
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	2515593
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_308
# 判決種類	民事判決
# ---------------------------
# 律師	[0, [u'\u5289\u9d3b\u57fa\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	6495565
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_316
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5f35\u7e7c\u6e96\u5f8b\u5e2b', u'\u5f90\u7950\u5049\u5f8b\u5e2b'], [u'\u694a\u69ae\u5bcc\u5f8b\u5e2b', u'\u8523\u5fd7\u660e\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	1108815
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_33
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u9673\u6b66\u748b\u5f8b\u5e2b', u'\u9673\u6167\u82ac\u5f8b\u5e2b'], [u'\u6d2a\u5d07\u6b3d\u5f8b\u5e2b', u'\u694a\u4fca\u5f65\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	326449
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_333
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	18727203
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_338
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5f90\u66c9\u840d\u5f8b\u5e2b'], [u'\u7f85\u570b\u658c\u5f8b\u5e2b\r']]
# 地點	臺中
# 判決金額	1682839
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_339
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5f35\u6176\u5b97\u5f8b\u5e2b', u'\u8b1d\u5c1a\u4fee\u5f8b\u5e2b'], [u'\u8881\u70c8\u8f1d\u5f8b\u5e2b', u'\u856d\u6176\u9234\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_重訴_377
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	880000
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_386
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u7f85\u5b97\u8ce2\u5f8b\u5e2b', u'\u6797\u5a01\u6210\u5f8b\u5e2b'], 0]
# 地點	臺中
# 判決金額	5409256
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_402
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	228926
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_404
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	180540
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_407
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u838a\u6176\u6d32\u5f8b\u5e2b', u'\u6d2a\u8559\u8339\u5f8b\u5e2b', u'\u9673\u8208\u84c9\u5f8b\u5e2b\r'], [u'\ue3ad\u6986\u653f\u5f8b\u5e2b', u'\u838a\u60e0\u840d\u5f8b\u5e2b\r', u'\u6731\u4ed9\u8389\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_重訴_412
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u859b\u4efb\u667a\u5f8b\u5e2b'], [u'\u6797\u6587\u6210\u5f8b\u5e2b']]
# 地點	臺中
# 判決金額	3687447
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_425
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	2757243
# 原告勝訴	True
# 判決名稱	臺中_101_重訴_429
# 判決種類	民事判決
# ---------------------------
# 律師	[[u'\u5f35\u79c0\u745c\u5f8b\u5e2b', u'\u9673\u5927\u4fca\u5f8b\u5e2b\r'], 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_重訴_45
# 判決種類	民事判決
# ---------------------------
# 律師	[0, 0]
# 地點	臺中
# 判決金額	0
# 原告勝訴	False
# 判決名稱	臺中_101_重訴_452
# 判決種類	民事判決
# ---------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-225-1d269d8d3306> in <module>()
#      23     dic[u'判決種類'] = get_judgement_type(ls)
#      24     dic[u'律師']=list(get_lawyer(ls))
# ---> 25     dic[u'判決金額'] = get_money(ls)
#      26
#      27     for x in dic:
#
# <ipython-input-219-c4dfb70db573> in get_money(ls)
#      21             return int(money)
#      22         except:
# ---> 23             total = transform(money)
#      24             return total
#      25     else:
#
# <ipython-input-218-e691a5594f7a> in transform(money)
#      61             num+=1
#      62             get_n.append(0)
# ---> 63             get_m.append(money_unit[money[num]])
#      64
#      65
#
# KeyError: u'\u8086'

# %%
print u'\u859b\u4efb\u667a\u5f8b\u5e2b'
# Out:
# 薛任智律師
