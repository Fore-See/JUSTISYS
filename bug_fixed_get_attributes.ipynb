# %%
def get_lawyer(ls):

    num  = len(ls)

    #因為律師可能不只一個所以塞進list裡面
    Plaintiffs_lawyer = []
    Defendants_lawyer = []
    for i in range(0,num):
        ls[i] = ls[i].replace(u'　',u'').replace(u' ',u'')
        #find Plaintiff 's lawyer
        if ls[i].find(u'原告') != -1:
            for terminal in range(1,20):
                next_line = ls[i+terminal].replace(u'　',u'').replace(u' ',u'')
                if next_line.find(u'被告') != -1:
                    break
                if next_line.find(u'律師') != -1:
                    if len(next_line)>5:
                        if u'複代理人' in next_line:
                            next_line = next_line.split(u'複代理人')[1]
                            people = next_line.find(u'律師')
                            Plaintiffs_lawyer.append(next_line[:people+2])
                            continue
                            
                        elif len(next_line)>10:
                            people = next_line.find(u'人')
                            law = next_line.find(u'律師')
                            Plaintiffs_lawyer.append(next_line[people+1:law+2])
                            continue
                            
                        elif u'共同訴訟代' in next_line:
                            cor = next_line.find(u'共同')
                            Plaintiffs_lawyer.append(next_line[cor+5:])
                            continue
                        
                        elif u'共同' in next_line and u'訴訟代' not in next_line:
                            cor = next_line.find(u'共同')
                            Plaintiffs_lawyer.append(next_line[cor+2:])
                            continue
                            
                        else:
                            people = next_line.find(u'人')
                            Plaintiffs_lawyer.append(next_line[people+1:])
                    else:
                        Plaintiffs_lawyer.append(next_line)


        #find Defendant 's lawyer
        if u'被告' in ls[i]:
            
            for terminal in range(1,20):
                next_line = ls[i+terminal].replace(u'　',u'').replace(u' ',u'')
                if u'主文' in next_line:
                    break
                    
                if u'律師' in next_line:
                    if len(next_line)>5:
                        if u'複代理人' in next_line:
                            next_line = next_line.split(u'複代理人')[1]
                            people = next_line.find(u'律師')
                            Defendants_lawyer.append(next_line[:people+2])
                            continue
                            
                        elif len(next_line)>10:
                            people = next_line.find(u'人')
                            law = next_line.find(u'律師')
                            Defendants_lawyer.append(next_line[people+1:law+2])
                            continue
                            
                        elif u'共同訴訟代' in next_line:
                            cor = next_line.find(u'共同')
                            Defendants_lawyer.append(next_line[cor+5:])
                            continue
                        
                        elif u'共同' in next_line and u'訴訟代' not in next_line:
                            cor = next_line.find(u'共同')
                            Defendants_lawyer.append(next_line[cor+2:])
                            continue

                        else:
                            people = next_line.find(u'人')
                            Defendants_lawyer.append(next_line[people+1:])
                    else:
                        Defendants_lawyer.append(next_line)
            break
    
#     for i in Plaintiffs_lawyer:
#         print len(i),i
#     print '---'
#     for i in Defendants_lawyer:
#         print len(i),i
    Plaintiffs_lawyer = Plaintiffs_lawyer if len(Plaintiffs_lawyer) != 0 else 0
    Defendants_lawyer = Defendants_lawyer if len(Defendants_lawyer) != 0 else 0
    return Plaintiffs_lawyer , Defendants_lawyer
    

print 'def get_lawyer(ls) set'
# Out:
# def get_lawyer(ls) set

# %%
def Plaintiff_win(ls):
    start = 0
    stop = 150
    for i in range(len(ls)):
        line = ls[i].replace(u'　',u'').replace(u' ',u'').strip()
        if u'主文' in line:
            start = i
        if u'事實' in line or u'理由' in line:
            stop = i
            break

    if u'給付' in '\n'.join(ls[start:stop]):
        return True
    else:
        return False        

print 'def Plaintiff_win(ls) set'
# Out:
# def Plaintiff_win(ls) set

# %%
def get_judgement_type(ls):
    for line in ls:
        if u'地方法院' in line:
            if u'簡易庭' in line:
                start_pos = line.find(u'簡易庭')
                judgement_type = line.split(u'　')[0][start_pos+3:].encode('utf-8')
                return judgement_type.decode('utf-8')
                break    
            start_pos = line.find(u'地方法院')
            judgement_type = line.split(u'　')[0][start_pos+4:].encode('utf-8')
            return judgement_type.decode('utf-8')
            break
print 'def get_judgement_type(ls) set'
# Out:
# def get_judgement_type(ls) set

# %%
'''
for test transform()
'''
transform(u'參萬參仟零壹拾陸')
transform(u'捌萬元')
# Out:
# 80000

# %%
#方法 transform-----輸入 money
def transform(money):
    num=0      #for 中文數字的第幾個位置
    total = 0  #for 數字總合
    #------------
    get_m = [] #塞入money_unit

    get_n = [] #塞入number
    #------------
    print money #印出中文大寫數字
    #------------
    
    money_unit ={u'萬':10000,u'仟':1000,u'佰':100,u'拾':10,u'千':1000,u'百':100,u'十':10}
    number={u'零':0,u'壹':1,u'貳':2,u'參':3,u'肆':4,\
            u'伍':5,u'陸':6,u'柒':7,u'捌':8,u'玖':9,\
            u'一':1,u'二':2,u'三':3,u'四':4,\
            u'五':5,u'六':6,u'七':7,u'八':8,u'九':9}
    
    
    for x in range(0,len(money)):
        if money[num]==u'零':#若是0就跳過
            num+=1
            continue
        elif money[num] in number:#若是 數字 開頭
            if num==len(money)-1:#判斷是否目前位置等於總長度    相等 是有個位數
                get_n.append(number[money[num]])
                get_m.append(1)
                break

            get_n.append(number[money[num]])
            num+=1

            get_m.append(money_unit[money[num]])

            if num==len(money)-1:#若是沒有個位數 就直接結束
                break
            num+=1

            if money[num] in money_unit:#只看是否是 萬  eg  壹拾"萬"
                get_n.append(0)
                get_m.append(money_unit[money[num]])
                if num==len(money)-1:
                    break
                num+=1

#                 if num==len(money)-1:#若是沒有個位數 就直接結束
#                     break

        elif money[num] in money_unit:#若是 十 開頭  eg  拾萬
            get_n.append(1)
            get_m.append(10)
            num+=1
            if money[num] in number:
                get_n.append(number[money[num]])
                num+=1
                get_m.append(money_unit[money[num]])
                if num==len(money)-1:
                    break
                num+=1
                continue
                
                
            get_n.append(0)
            get_m.append(money_unit[money[num]])
            
            
            if num==len(money)-1:
                break
                
            num+=1
            
            if money[num] in money_unit:
                #print num,0,money_unit[money[num]],'shit'

                get_n.append(0)
                get_m.append(money_unit[money[num]])
                num+=1

                if num==len(money)-1:
                    break

    #運用get_n get_m 倆倆一組 開始相乘
    times = len(get_n) if get_n>get_m else len(get_m)
    
    if 10000 in get_m:                 #若是有 "萬"
        change = get_m.index(10000)    #找出萬的位置
        for x in range(0,change):      #萬以前的單位 get_m 都乘 10000
            get_m[x] = get_m[x]*10000

    for x in range(0,times):           #get_m * get_n 在相加到 total
        total+=get_n[x]*get_m[x]
    
    return total
#     print '判賠金額 - %d'%total
print 'def transform(ls) set'
# Out:
# def transform(ls) set

# %%
def get_money(ls):
    for i in range(len(ls)):
        start = 0
        stop = 150
        ls[i] = ls[i].replace(u'　',u'').replace(u' ',u'').strip()
        if u'主文' in ls[i]:
            start = i
        if u'事實' in ls[i] or u'理由' in ls[i]:
            stop = i
            break
            
    content = u''.join(ls[start:stop]).replace(u',','')
#     print content
    if u'給付' in content:
        dollars = content.find(u'元')
        nt = content.find(u'幣')
        money = content[nt+1:dollars]
#         print money
        try:
            return int(money)
        except:
            total = transform(money)
            return total
    else:
        return 0
    
print 'def get_money(ls) set'
# Out:
# def get_money(ls) set

# %%
import os
import codecs
os.remove('data.txt')
with codecs.open('data.txt','a','utf-8') as fd:
    fd.write('%s\t%s\t%s\t%s\t%s\t%s\r\n'%(u'地點',u'判決名稱',u'判決種類',u'判決金額',u'原告勝訴',u'律師'))
dic = {
    u'地點':'',
    u'判決名稱':'',
    u'判決種類':'',
    u'判決金額':'',
    u'原告勝訴':'',
    u'律師':''
}
no = 0
location = u'project\\verdict\\'
all_files = os.path.abspath(location)
for x in os.listdir(all_files)[:]:
    
    place = x.split(u'_')[0]
    dic[u'地點'] = place
    dic[u'判決名稱'] = x.split('.')[0]
    with codecs.open(os.path.join(location,x),'r','utf-8') as f:
        no+=1
        print no,x
        ls = []
        for line in f:
            if line.strip() != 0:
                ls.append(line)
    dic[u'原告勝訴'] = Plaintiff_win(ls)
    dic[u'判決種類'] = get_judgement_type(ls)
    dic[u'律師']=list(get_lawyer(ls))
    dic[u'判決金額'] = get_money(ls)
    
    with codecs.open('data.txt','a','utf-8') as fd:
#         u'地點':'',u'判決名稱':'',u'判決種類':'',u'判決金額':'',u'原告勝訴':'',u'律師':''
        fd.write('%s\t%s\t%s\t%s\t%s\t%s\r\n'%(dic[u'地點'],\
                                           dic[u'判決名稱'],\
                                           dic[u'判決種類'],\
                                           dic[u'判決金額'],\
                                           dic[u'原告勝訴'],\
                                           dic[u'律師']))
#         fd.write('---------------------------\r\n')
    print '%s\t%s\t%s\t%s\t%s\t%s\r\n'%(dic[u'地點'],\
                                        dic[u'判決名稱'],\
                                        dic[u'判決種類'],\
                                        dic[u'判決金額'],\
                                        dic[u'原告勝訴'],\
                                        dic[u'律師'])

print 'done'
# Out:
# 1 南投_100_埔小_1.txt
# 南投	南投_100_埔小_1	民事小額判決	0	False	[0, 0]
#
# 2 南投_100_埔小_112.txt
# 壹萬參仟伍佰玖拾壹
# 南投	南投_100_埔小_112	小額民事判決	13591	True	[0, 0]
#
# 3 南投_100_埔小_2.txt
# 伍萬參仟零玖拾捌
# 南投	南投_100_埔小_2	民事小額判決	53098	True	[0, 0]
#
# 4 南投_100_埔小_81.txt
# 肆萬柒仟零伍拾參
# 南投	南投_100_埔小_81	民事小額判決	47053	True	[0, 0]
#
# 5 南投_100_埔簡_113.txt
# 貳萬壹仟壹佰貳拾
# 南投	南投_100_埔簡_113	民事簡易判決	21120	True	[0, 0]
#
# 6 南投_100_埔簡_128.txt
# 參萬
# 南投	南投_100_埔簡_128	民事簡易判決	30000	True	[0, 0]
#
# 7 南投_100_埔簡_131.txt
# 柒萬參仟玖佰肆拾伍
# 南投	南投_100_埔簡_131	民事簡易判決	73945	True	[0, 0]
#
# 8 南投_100_埔簡_153.txt
# 壹拾伍萬捌仟柒佰
# 南投	南投_100_埔簡_153	民事簡易判決	158700	True	[0, 0]
#
# 9 南投_100_埔簡_22.txt
# 貳萬貳仟捌佰玖拾壹
# 南投	南投_100_埔簡_22	民事簡易判決	22891	True	[0, 0]
#
# 10 南投_100_埔簡_46.txt
# 壹拾壹萬貳仟貳佰肆拾
# 南投	南投_100_埔簡_46	民事簡易判決	112240	True	[0, 0]
#
# 11 南投_100_埔簡_47.txt
# 玖萬柒仟貳佰
# 南投	南投_100_埔簡_47	民事簡易判決	97200	True	[0, 0]
#
# 12 南投_100_投勞簡_7.txt
# 南投	南投_100_投勞簡_7	民事簡易判決	0	False	[0, 0]
#
# 13 南投_100_投小_104.txt
# 貳萬伍仟肆佰捌拾伍
# 南投	南投_100_投小_104	民事小額判決	25485	True	[0, 0]
#
# 14 南投_100_投小_12.txt
# 參萬肆仟參佰玖拾伍
# 南投	南投_100_投小_12	民事小額判決	34395	True	[0, 0]
#
# 15 南投_100_投小_127.txt
# 壹萬零伍佰肆拾參
# 南投	南投_100_投小_127	民事小額判決	10543	True	[0, 0]
#
# 16 南投_100_投小_129.txt
# 參仟陸佰壹拾柒
# 南投	南投_100_投小_129	民事小額判決	3617	True	[0, 0]
#
# 17 南投_100_投小_131.txt
# 壹萬捌仟柒佰玖拾貳
# 南投	南投_100_投小_131	民事小額判決	18792	True	[0, 0]
#
# 18 南投_100_投小_146.txt
# 玖萬肆仟貳佰
# 南投	南投_100_投小_146	民事小額判決	94200	True	[0, 0]
#
# 19 南投_100_投小_158.txt
# 南投	南投_100_投小_158	民事小額判決	0	False	[0, 0]
#
# 20 南投_100_投小_162.txt
# 貳萬肆仟
# 南投	南投_100_投小_162	民事小額判決	24000	True	[0, 0]
#
# 21 南投_100_投小_166.txt
# 貳萬貳仟零陸拾陸
# 南投	南投_100_投小_166	民事小額判決	22066	True	[0, 0]
#
# 22 南投_100_投小_197.txt
# 捌仟柒佰壹拾伍
# 南投	南投_100_投小_197	民事小額判決	8715	True	[0, 0]
#
# 23 南投_100_投小_214.txt
# 壹萬柒仟伍佰陸拾
# 南投	南投_100_投小_214	民事小額判決	17560	True	[0, 0]
#
# 24 南投_100_投小_221.txt
# 貳萬
# 南投	南投_100_投小_221	民事小額判決	20000	True	[0, 0]
#
# 25 南投_100_投小_253.txt
# 參萬
# 南投	南投_100_投小_253	民事小額判決	30000	True	[0, 0]
#
# 26 南投_100_投小_264.txt
# 肆萬參仟貳佰壹拾壹
# 南投	南投_100_投小_264	民事小額判決	43211	True	[0, 0]
#
# 27 南投_100_投小_289.txt
# 玖仟參佰陸拾伍
# 南投	南投_100_投小_289	民事小額判決	9365	True	[0, 0]
#
# 28 南投_100_投小_30.txt
# 壹萬伍仟捌佰陸拾伍
# 南投	南投_100_投小_30	民事小額判決	15865	True	[0, 0]
#
# 29 南投_100_投小_300.txt
# 壹萬參仟壹佰參拾伍
# 南投	南投_100_投小_300	民事小額判決	13135	True	[0, 0]
#
# 30 南投_100_投小_334.txt
# 壹萬肆仟零貳拾壹
# 南投	南投_100_投小_334	小額民事判決	14021	True	[0, 0]
#
# 31 南投_100_投小_387.txt
# 陸萬壹仟參佰柒拾肆
# 南投	南投_100_投小_387	民事小額判決	61374	True	[0, 0]
#
# 32 南投_100_投小_397.txt
# 參萬伍仟
# 南投	南投_100_投小_397	民事小額判決	35000	True	[0, 0]
#
# 33 南投_100_投小_96.txt
# 貳萬零柒佰陸拾參
# 南投	南投_100_投小_96	民事小額判決	20763	True	[0, 0]
#
# 34 南投_100_投簡_116.txt
# 壹萬伍仟壹佰捌拾玖
# 南投	南投_100_投簡_116	民事簡易判決	15189	True	[0, 0]
#
# 35 南投_100_投簡_157.txt
# 貳拾參萬捌仟玖佰柒拾參
# 南投	南投_100_投簡_157	民事簡易判決	238973	True	[0, 0]
#
# 36 南投_100_投簡_16.txt
# 玖萬壹仟捌佰肆拾柒
# 南投	南投_100_投簡_16	民事簡易判決	91847	True	[0, 0]
#
# 37 南投_100_投簡_200.txt
# 肆萬玖仟肆佰貳拾捌
# 南投	南投_100_投簡_200	民事簡易判決	49428	True	[0, 0]
#
# 38 南投_100_投簡_244.txt
# 貳拾貳萬貳仟
# 南投	南投_100_投簡_244	民事簡易判決	222000	True	[0, 0]
#
# 39 南投_100_投簡_260.txt
# 壹拾捌萬陸仟捌佰壹拾壹
# 南投	南投_100_投簡_260	民事簡易判決	186811	True	[0, 0]
#
# 40 南投_100_投簡_306.txt
# 壹拾貳萬玖仟參佰柒拾陸
# 南投	南投_100_投簡_306	民事簡易判決	129376	True	[[u'\u6797\u76ca\u8f1d\u5f8b\u5e2b'], 0]
#
# 41 南投_100_投簡_314.txt
# 捌萬
# 南投	南投_100_投簡_314	民事簡易判決	80000	True	[0, 0]
#
# 42 南投_100_投簡_317.txt
# 南投	南投_100_投簡_317	民事簡易判決	0	False	[0, 0]
#
# 43 南投_100_投簡_334.txt
# 柒萬捌仟柒佰玖拾玖
# 南投	南投_100_投簡_334	民事簡易判決	78799	True	[0, 0]
#
# 44 南投_100_投簡_338.txt
# 伍仟伍佰捌拾柒
# 南投	南投_100_投簡_338	民事簡易判決	5587	True	[0, 0]
#
# 45 南投_100_投簡_348.txt
# 參萬肆仟陸佰壹拾貳
# 南投	南投_100_投簡_348	民事簡易判決	34612	True	[0, 0]
#
# 46 南投_100_投簡_51.txt
# 伍拾萬
# 南投	南投_100_投簡_51	民事簡易判決	500000	True	[0, 0]
#
# 47 南投_100_訴_111.txt
# 壹拾伍萬
# 南投	南投_100_訴_111	民事判決	150000	True	[0, 0]
#
# 48 南投_100_訴_114.txt
#
# 南投	南投_100_訴_114	民事判決	0	True	[0, 0]
#
# 49 南投_100_訴_115.txt
# 玖萬壹仟肆佰柒拾貳
# 南投	南投_100_訴_115	民事判決	91472	True	[[u'\u5433\u6600\u965e\u5f8b\u5e2b', u'\u5433\u6600\u965e\u5f8b\u5e2b'], [u'\u6797\u5efa\u5b8f\u5f8b\u5e2b', u'\u99ae\u9266\u55bb\u5f8b\u5e2b']]
#
# 50 南投_100_訴_116.txt
# 伍拾貳萬伍仟玖佰伍拾伍
# 南投	南投_100_訴_116	民事判決	525955	True	[[u'\u5ed6\u6dd1\u83ef\u5f8b\u5e2b'], 0]
#
# 51 南投_100_訴_149.txt
# 貳拾萬
# 南投	南投_100_訴_149	民事判決	200000	True	[0, [u'\u6d2a\u5d07\u6b3d\u5f8b\u5e2b']]
#
# 52 南投_100_訴_167.txt
# 捌拾玖萬柒仟捌佰參拾肆
# 南投	南投_100_訴_167	民事判決	897834	True	[0, 0]
#
# 53 南投_100_訴_173.txt
# 柒拾壹萬肆仟伍佰玖拾壹
# 南投	南投_100_訴_173	民事判決	714591	True	[0, 0]
#
# 54 南投_100_訴_192.txt
# 壹佰壹拾伍萬零陸佰參拾貳
# 南投	南投_100_訴_192	民事判決	1150632	True	[0, [u'\u5f90\u6587\u5b97\u5f8b\u5e2b']]
#
# 55 南投_100_訴_193.txt
# 壹佰肆拾玖萬肆仟零玖拾肆
# 南投	南投_100_訴_193	民事判決	1494094	True	[[u'\u9673\u76c8\u58fd\u5f8b\u5e2b'], 0]
#
# 56 南投_100_訴_20.txt
# 參拾萬
# 南投	南投_100_訴_20	民事判決	300000	True	[0, 0]
#
# 57 南投_100_訴_201.txt
# 南投	南投_100_訴_201	民事判決	0	False	[[u'\u5ed6\u5fd7\u582f\u5f8b\u5e2b'], [u'\u9673\u4fee\u4ec1\u5f8b\u5e2b']]
#
# 58 南投_100_訴_204.txt
# 伍萬
# 南投	南投_100_訴_204	民事判決	50000	True	[[u'\u6797\u4f38\u5168\u5f8b\u5e2b', u'\u6797\u4f38\u5168\u5f8b\u5e2b', u'\u6797\u4f38\u5168\u5f8b\u5e2b'], 0]
#
# 59 南投_100_訴_208.txt
# 壹拾萬肆仟貳佰壹拾壹
# 南投	南投_100_訴_208	民事判決	104211	True	[0, 0]
#
# 60 南投_100_訴_209.txt
# 壹拾萬
# 南投	南投_100_訴_209	民事判決	100000	True	[0, 0]
#
# 61 南投_100_訴_287.txt
# 壹佰萬零肆仟零捌拾肆
# 南投	南投_100_訴_287	民事判決	1004084	True	[0, [u'\u738b\u6587\u8056\u5f8b\u5e2b']]
#
# 62 南投_100_訴_304.txt
# 參拾貳萬零陸拾柒
# 南投	南投_100_訴_304	民事判決	320067	True	[0, 0]
#
# 63 南投_100_訴_312.txt
# 貳拾萬
# 南投	南投_100_訴_312	民事判決	200000	True	[0, [u'\u6797\u842c\u751f\u5f8b\u5e2b']]
#
# 64 南投_100_訴_32.txt
# 伍拾參萬肆仟捌佰捌拾捌
# 南投	南投_100_訴_32	民事判決	534888	True	[0, [u'\u8521\u9806\u5c45\u5f8b\u5e2b']]
#
# 65 南投_100_訴_326.txt
# 肆拾玖萬肆仟捌佰壹拾柒
# 南投	南投_100_訴_326	民事判決	494817	True	[[u'\u8607\u975c\u6021\u5f8b\u5e2b', u'\u7f85\u8c50\u80e4\u5f8b\u5e2b\r'], [u'\u5f35\u5d07\u54f2\u5f8b\u5e2b', u'\u5f35\u4ed5\u878d\u5f8b\u5e2b', u'\u5f35\u85dd\u9a30\u5f8b\u5e2b\r']]
#
# 66 南投_100_訴_339.txt
# 貳拾萬壹仟參佰伍拾伍
# 南投	南投_100_訴_339	民事判決	201355	True	[0, 0]
#
# 67 南投_100_訴_340.txt
# 肆拾伍萬肆仟玖佰貳拾陸
# 南投	南投_100_訴_340	民事判決	454926	True	[0, 0]
#
# 68 南投_100_訴_343.txt
# 參拾萬
# 南投	南投_100_訴_343	民事判決	300000	True	[[u'\u66fe\u742c\u9234\u5f8b\u5e2b'], 0]
#
# 69 南投_100_訴_344.txt
# 貳拾貳萬伍仟參佰肆拾壹
# 南投	南投_100_訴_344	民事判決	225341	True	[0, 0]
#
# 70 南投_100_訴_366.txt
# 南投	南投_100_訴_366	民事判決	0	False	[[u'\u6d2a\u660e\u5112\u5f8b\u5e2b', u'\u5433\u5b9c\u661f\u5f8b\u5e2b'], [u'\u6731\u6587\u8ca1\u5f8b\u5e2b']]
#
# 71 南投_100_訴_368.txt
# 陸萬
# 南投	南投_100_訴_368	民事判決	60000	True	[[u'\u8521\u745e\u7159\u5f8b\u5e2b'], 0]
#
# 72 南投_100_訴_370.txt
# 捌萬捌仟肆佰陸拾捌
# 南投	南投_100_訴_370	民事判決	88468	True	[0, 0]
#
# 73 南投_100_訴_50.txt
# 肆萬肆仟貳佰柒拾貳
# 南投	南投_100_訴_50	民事判決	44272	True	[0, 0]
#
# 74 南投_100_訴_6.txt
# 參拾貳萬伍仟貳佰肆拾捌
# 南投	南投_100_訴_6	民事判決	325248	True	[0, [u'\u9673\u570b\u83ef\u5f8b\u5e2b']]
#
# 75 南投_100_重訴_14.txt
#
# 南投	南投_100_重訴_14	民事判決	0	True	[[u'\u9ec3\u9756\u9594\u5f8b\u5e2b'], 0]
#
# 76 南投_100_重訴_19.txt
# 壹拾柒萬玖仟捌佰貳拾伍
# 南投	南投_100_重訴_19	民事判決	179825	True	[[u'\u5f35\u5d07\u54f2\u5f8b\u5e2b', u'\u694a\u4f73\u52f3\u5f8b\u5e2b', u'\u5f35\u5d07\u54f2\u5f8b\u5e2b', u'\u694a\u4f73\u52f3\u5f8b\u5e2b', u'\u912d\u5f18\u660e\u5f8b\u5e2b\r', u'\u5f35\u85dd\u9a30\u5f8b\u5e2b\r'], 0]
#
# 77 南投_100_重訴_2.txt
# 壹仟柒佰肆拾萬貳仟肆佰玖拾柒
# 南投	南投_100_重訴_2	民事判決	17402497	True	[[u'\u5f35\u82f1\u4e00\u5f8b\u5e2b', u'\u8b1d\u5b8f\u5049\u5f8b\u5e2b'], 0]
#
# 78 南投_100_重訴_23.txt
# 壹佰柒拾參萬陸仟捌佰陸拾貳
# 南投	南投_100_重訴_23	民事判決	1736862	True	[[u'\u5468\u6625\u9716\u5f8b\u5e2b'], [u'\u5f90\u6587\u5b97\u5f8b\u5e2b']]
#
# 79 南投_100_重訴_33.txt
# 壹佰伍拾陸萬壹仟捌佰拾伍
# 南投	南投_100_重訴_33	民事判決	1561805	True	[[u'\u9ec3\u6587\u7687\u5f8b\u5e2b'], 0]
#
# 80 南投_100_重訴_34.txt
# 貳佰伍拾壹萬貳仟壹佰陸拾
# 南投	南投_100_重訴_34	民事判決	2512160	True	[[u'\u8521\u5fd7\u5fe0\u5f8b\u5e2b'], [u'\u738b\u6587\u8056\u5f8b\u5e2b']]
#
# 81 南投_100_重訴_35.txt
# 伍佰伍拾貳萬參仟伍佰壹拾壹
# 南投	南投_100_重訴_35	民事判決	5523511	True	[0, [u'\u738b\u6587\u8056\u5f8b\u5e2b']]
#
# 82 南投_100_重訴_36.txt
# 壹佰柒拾捌萬伍仟柒佰壹拾伍
# 南投	南投_100_重訴_36	民事判決	1785715	True	[0, [u'\u738b\u6587\u8056\u5f8b\u5e2b']]
#
# 83 南投_100_重訴_43.txt
# 陸拾貳萬壹仟捌佰陸拾伍
# 南投	南投_100_重訴_43	民事判決	621865	True	[[u'\u6c5f\u9298\u6817\u5f8b\u5e2b'], [u'\u6731\u6587\u8ca1\u5f8b\u5e2b']]
#
# 84 南投_101_勞訴_10.txt
#
# 南投	南投_101_勞訴_10	民事判決	0	True	[[u'\u5f35\u4ed5\u878d\u5f8b\u5e2b'], 0]
#
# 85 南投_101_勞訴_2.txt
# 參拾貳萬零柒佰壹拾
# 南投	南投_101_勞訴_2	民事判決	320710	True	[[u'\u738b\u58eb\u9298\u5f8b\u5e2b'], [u'\u5289\u5efa\u6210\u5f8b\u5e2b']]
#
# 86 南投_101_勞訴_6.txt
# 貳佰玖拾伍萬零肆佰參拾
# 南投	南投_101_勞訴_6	民事判決	2950430	True	[[u'\u65bd\u745e\u7ae0\u5f8b\u5e2b'], [u'\u5ed6\u5fd7\u582f\u5f8b\u5e2b']]
#
# 87 南投_101_勞訴_7.txt
# 南投	南投_101_勞訴_7	民事判決	0	False	[[u'\u694a\u5fd7\u822a\u5f8b\u5e2b'], [u'\u8521\u5f97\u8b19\u5f8b\u5e2b', u'\u6c5f\u5065\u92d2\u5f8b\u5e2b']]
#
# 88 南投_101_埔小_128.txt
# 捌仟伍佰捌拾肆
# 南投	南投_101_埔小_128	民事小額判決	8584	True	[0, 0]
#
# 89 南投_101_埔小_149.txt
# 貳萬肆仟玖佰玖拾貳
# 南投	南投_101_埔小_149	民事小額判決	24992	True	[0, 0]
#
# 90 南投_101_埔小_154.txt
# 捌仟
# 南投	南投_101_埔小_154	民事簡易判決	8000	True	[0, 0]
#
# 91 南投_101_埔小_23.txt
# 貳萬壹仟玖佰捌拾貳
# 南投	南投_101_埔小_23	民事小額判決	21982	True	[0, 0]
#
# 92 南投_101_埔小_30.txt
# 陸仟捌佰伍拾柒
# 南投	南投_101_埔小_30	小額民事判決	6857	True	[0, 0]
#
# 93 南投_101_埔小_34.txt
# 貳萬玖仟陸佰伍拾柒
# 南投	南投_101_埔小_34	小額民事判決	29657	True	[0, 0]
#
# 94 南投_101_埔小_53.txt
# 陸仟捌佰參拾伍
# 南投	南投_101_埔小_53	民事小額判決	6835	True	[0, 0]
#
# 95 南投_101_埔小_72.txt
# 壹萬伍仟伍佰參拾柒
# 南投	南投_101_埔小_72	民事小額判決	15537	True	[0, 0]
#
# 96 南投_101_埔小_76.txt
# 壹萬捌仟玖佰柒拾柒
# 南投	南投_101_埔小_76	民事小額判決	18977	True	[0, 0]
#
# 97 南投_101_埔小_79.txt
# 玖仟壹佰參拾柒
# 南投	南投_101_埔小_79	民事小額判決	9137	True	[0, 0]
#
# 98 南投_101_埔小_93.txt
# 肆萬貳仟貳佰陸拾捌
# 南投	南投_101_埔小_93	民事小額判決	42268	True	[0, 0]
#
# 99 南投_101_埔小_94.txt
# 玖仟玖佰肆拾玖
# 南投	南投_101_埔小_94	民事小額判決	9949	True	[0, 0]
#
# 100 南投_101_埔小_95.txt
# 壹萬陸仟肆佰玖拾陸
# 南投	南投_101_埔小_95	小額民事判決	16496	True	[0, 0]
#
# 101 南投_101_埔簡_11.txt
# 參萬肆仟肆佰肆拾
# 南投	南投_101_埔簡_11	民事簡易判決	34440	True	[0, 0]
#
# 102 南投_101_埔簡_120.txt
# 壹拾捌萬柒仟壹佰參拾柒
# 南投	南投_101_埔簡_120	民事簡易判決	187137	True	[[u'\u9673\u5149\u9f8d\u5f8b\u5e2b'], 0]
#
# 103 南投_101_埔簡_133.txt
# 壹拾肆萬壹仟玖佰貳拾陸
# 南投	南投_101_埔簡_133	民事簡易判決	141926	True	[0, 0]
#
# 104 南投_101_埔簡_152.txt
# 貳萬零伍佰
# 南投	南投_101_埔簡_152	民事簡易判決	20500	True	[0, 0]
#
# 105 南投_101_埔簡_21.txt
# 陸萬參仟參仟貳拾玖
# 南投	南投_101_埔簡_21	民事簡易判決	66029	True	[0, 0]
#
# 106 南投_101_埔簡_37.txt
# 壹拾萬柒仟零捌拾參
# 南投	南投_101_埔簡_37	民事簡易判決	107083	True	[0, 0]
#
# 107 南投_101_埔簡_59.txt
# 陸萬參仟柒佰陸拾
# 南投	南投_101_埔簡_59	民事簡易判決	63760	True	[0, 0]
#
# 108 南投_101_埔簡_72.txt
# 陸萬伍仟陸佰參拾捌
# 南投	南投_101_埔簡_72	民事簡易判決	65638	True	[0, 0]
#
# 109 南投_101_埔簡_73.txt
# 肆萬貳仟陸佰捌拾玖
# 南投	南投_101_埔簡_73	民事簡易判決	42689	True	[0, 0]
#
# 110 南投_101_埔簡_98.txt
# 壹拾萬貳仟柒佰貳拾肆
# 南投	南投_101_埔簡_98	民事簡易判決	102724	True	[0, 0]
#
# 111 南投_101_建_2.txt
# 貳佰參拾玖萬伍仟玖佰貳拾壹
# 南投	南投_101_建_2	民事判決	2395921	True	[0, [u'\u5f35\u5fd7\u65b0\u5f8b\u5e2b', u'\u7f85\u8c50\u80e4\u5f8b\u5e2b', u'\u8607\u975c\u6021\u5f8b\u5e2b\r']]
#
# 112 南投_101_投小_141.txt
# 參萬伍仟玖佰貳拾玖
# 南投	南投_101_投小_141	民事小額判決	35929	True	[0, 0]
#
# 113 南投_101_投小_152.txt
# 肆仟參佰貳拾捌
# 南投	南投_101_投小_152	民事小額判決	4328	True	[0, 0]
#
# 114 南投_101_投小_160.txt
# 參萬肆仟捌佰貳拾捌
# 南投	南投_101_投小_160	民事小額判決	34828	True	[0, 0]
#
# 115 南投_101_投小_165.txt
# 壹萬捌仟壹佰陸拾陸
# 南投	南投_101_投小_165	民事小額判決	18166	True	[0, 0]
#
# 116 南投_101_投小_178.txt
#
# 南投	南投_101_投小_178	民事小額判決	0	True	[0, 0]
#
# 117 南投_101_投小_191.txt
# 玖仟壹佰玖拾玖
# 南投	南投_101_投小_191	小額民事判決	9199	True	[0, 0]
#
# 118 南投_101_投小_201.txt
# 肆萬參仟捌佰貳拾伍
# 南投	南投_101_投小_201	小額民事判決	43825	True	[0, 0]
#
# 119 南投_101_投小_207.txt
# 肆萬伍仟柒佰伍拾貳
# 南投	南投_101_投小_207	民事小額判決	45752	True	[0, 0]
#
# 120 南投_101_投小_229.txt
# 貳萬零貳佰肆拾捌
# 南投	南投_101_投小_229	民事小額判決	20248	True	[0, 0]
#
# 121 南投_101_投小_230.txt
# 壹萬零陸佰肆拾陸
# 南投	南投_101_投小_230	民事小額判決	10646	True	[0, 0]
#
# 122 南投_101_投小_238.txt
# 貳萬壹仟伍佰柒拾參
# 南投	南投_101_投小_238	民事小額判決	21573	True	[0, 0]
#
# 123 南投_101_投小_240.txt
# 壹萬玖仟零玖拾玖
# 南投	南投_101_投小_240	民事小額判決	19099	True	[0, 0]
#
# 124 南投_101_投小_253.txt
# 壹萬壹仟壹佰玖拾貳
# 南投	南投_101_投小_253	民事小額判決	11192	True	[0, 0]
#
# 125 南投_101_投小_27.txt
# 柒仟零捌拾
# 南投	南投_101_投小_27	民事小額判決	7080	True	[0, 0]
#
# 126 南投_101_投小_286.txt
# 貳萬伍仟壹佰捌拾
# 南投	南投_101_投小_286	民事小額判決	25180	True	[0, 0]
#
# 127 南投_101_投小_287.txt
# 參萬玖仟陸佰肆拾柒
# 南投	南投_101_投小_287	民事小額判決	39647	True	[0, 0]
#
# 128 南投_101_投小_293.txt
# 貳萬玖仟陸佰陸拾貳
# 南投	南投_101_投小_293	民事小額判決	29662	True	[0, 0]
#
# 129 南投_101_投小_299.txt
# 壹萬柒仟伍佰捌拾貳
# 南投	南投_101_投小_299	民事小額判決	17582	True	[0, 0]
#
# 130 南投_101_投小_311.txt
# 參萬陸仟
# 南投	南投_101_投小_311	民事小額判決	36000	True	[0, 0]
#
# 131 南投_101_投小_315.txt
# 壹萬肆仟零伍拾
# 南投	南投_101_投小_315	民事小額判決	14050	True	[0, 0]
#
# 132 南投_101_投小_338.txt
#
# 南投	南投_101_投小_338	民事小額判決	0	True	[0, 0]
#
# 133 南投_101_投小_339.txt
# 貳萬陸仟伍佰玖拾
# 南投	南投_101_投小_339	民事小額判決	26590	True	[0, 0]
#
# 134 南投_101_投小_349.txt
#
# 南投	南投_101_投小_349	民事小額判決	0	True	[0, 0]
#
# 135 南投_101_投小_350.txt
# 壹萬伍仟玖佰捌拾玖
# 南投	南投_101_投小_350	民事小額判決	15989	True	[0, 0]
#
# 136 南投_101_投小_360.txt
# 陸萬貳仟參佰玖拾參
# 南投	南投_101_投小_360	民事小額判決	62393	True	[0, 0]
#
# 137 南投_101_投小_413.txt
# 伍萬壹仟壹佰柒拾柒
# 南投	南投_101_投小_413	民事小額判決	51177	True	[0, 0]
#
# 138 南投_101_投小_91.txt
# 壹萬貳仟參佰貳拾陸
# 南投	南投_101_投小_91	民事小額判決	12326	True	[0, 0]
#
# 139 南投_101_投簡_122.txt
# 捌仟捌佰陸拾柒
# 南投	南投_101_投簡_122	民事簡易判決	8867	True	[0, 0]
#
# 140 南投_101_投簡_127.txt
#
# 南投	南投_101_投簡_127	民事簡易判決	0	True	[0, 0]
#
# 141 南投_101_投簡_128.txt
# 肆萬捌仟
# 南投	南投_101_投簡_128	民事簡易判決	48000	True	[0, 0]
#
# 142 南投_101_投簡_137.txt
# 壹拾萬壹仟貳佰捌拾
# 南投	南投_101_投簡_137	民事簡易判決	101280	True	[0, 0]
#
# 143 南投_101_投簡_169.txt
# 壹拾肆萬貳仟壹佰玖拾肆
# 南投	南投_101_投簡_169	民事簡易判決	142194	True	[0, 0]
#
# 144 南投_101_投簡_194.txt
# 壹拾萬陸仟零貳拾
# 南投	南投_101_投簡_194	民事簡易判決	106020	True	[0, 0]
#
# 145 南投_101_投簡_225.txt
# 柒萬肆仟捌佰伍拾
# 南投	南投_101_投簡_225	民事簡易判決	74850	True	[0, 0]
#
# 146 南投_101_投簡_226.txt
# 柒萬陸仟陸佰玖拾捌
# 南投	南投_101_投簡_226	民事簡易判決	76698	True	[0, 0]
#
# 147 南投_101_投簡_242.txt
# 壹拾伍萬伍仟玖佰玖拾伍
# 南投	南投_101_投簡_242	民事簡易判決	155995	True	[0, 0]
#
# 148 南投_101_投簡_244.txt
# 貳萬捌仟陸佰捌拾捌
# 南投	南投_101_投簡_244	民事簡易判決	28688	True	[0, 0]
#
# 149 南投_101_投簡_254.txt
# 柒萬伍仟壹佰捌拾伍
# 南投	南投_101_投簡_254	民事簡易判決	75185	True	[[u'\u6797\u5821\u6b3d\u5f8b\u5e2b'], 0]
#
# 150 南投_101_投簡_257.txt
# 壹萬柒仟壹佰陸拾陸
# 南投	南投_101_投簡_257	民事簡易判決	17166	True	[0, 0]
#
# 151 南投_101_投簡_268.txt
# 參仟肆佰玖拾貳
# 南投	南投_101_投簡_268	民事簡易判決	3492	True	[0, 0]
#
# 152 南投_101_投簡_296.txt
# 拾伍萬壹仟柒佰柒拾肆
# 南投	南投_101_投簡_296	民事簡易判決	151774	True	[0, 0]
#
# 153 南投_101_投簡_310.txt
# 南投	南投_101_投簡_310	民事簡易判決	0	False	[0, 0]
#
# 154 南投_101_投簡_311.txt
# 壹萬柒仟零陸拾
# 南投	南投_101_投簡_311	民事簡易判決	17060	True	[[u'\u9ec3\u9038\u4ec1\u5f8b\u5e2b'], 0]
#
# 155 南投_101_投簡_326.txt
# 玖萬貳仟柒佰零肆
# 南投	南投_101_投簡_326	民事簡易判決	92704	True	[0, 0]
#
# 156 南投_101_投簡_335.txt
# 參萬
# 南投	南投_101_投簡_335	民事簡易判決	30000	True	[0, 0]
#
# 157 南投_101_投簡_368.txt
# 拾參萬陸仟參佰捌拾
# 南投	南投_101_投簡_368	民事簡易判決	136380	True	[0, 0]
#
# 158 南投_101_投簡_419.txt
# 陸萬捌仟壹佰捌拾
# 南投	南投_101_投簡_419	民事簡易判決	68180	True	[0, 0]
#
# 159 南投_101_投簡_431.txt
# 南投	南投_101_投簡_431	民事簡易判決	0	False	[0, 0]
#
# 160 南投_101_投簡_97.txt
# 肆萬捌仟壹佰貳拾伍
# 南投	南投_101_投簡_97	民事簡易判決	48125	True	[0, 0]
#
# 161 南投_101_訴_109.txt
# 捌萬
# 南投	南投_101_訴_109	民事判決	80000	True	[0, 0]
#
# 162 南投_101_訴_114.txt
# 壹佰萬柒仟捌佰柒拾
# 南投	南投_101_訴_114	民事判決	1007870	True	[[u'\u5ed6\u5fd7\u582f\u5f8b\u5e2b'], [u'\u674e\u6548\u6587\u5f8b\u5e2b']]
#
# 163 南投_101_訴_137.txt
# 參拾柒萬捌仟
# 南投	南投_101_訴_137	民事判決	378000	True	[0, 0]
#
# 164 南投_101_訴_148.txt
# 肆拾貳萬參仟貳佰肆拾肆
# 南投	南投_101_訴_148	民事判決	423244	True	[0, 0]
#
# 165 南投_101_訴_163.txt
# 貳拾壹萬捌仟零伍拾參
# 南投	南投_101_訴_163	民事判決	218053	True	[0, 0]
#
# 166 南投_101_訴_164.txt
#
# 南投	南投_101_訴_164	民事判決	0	True	[0, 0]
#
# 167 南投_101_訴_168.txt
# 壹拾玖萬玖仟零捌拾捌
# 南投	南投_101_訴_168	民事判決	199088	True	[0, 0]
#
# 168 南投_101_訴_196.txt
# 南投	南投_101_訴_196	民事判決	0	False	[0, [u'\u8a31\u6f22\u9130\u5f8b\u5e2b']]
#
# 169 南投_101_訴_221.txt
# 捌拾柒萬肆仟參佰壹拾伍
# 南投	南投_101_訴_221	民事判決	874315	True	[0, 0]
#
# 170 南投_101_訴_227.txt
# 南投	南投_101_訴_227	民事判決	0	False	[0, 0]
#
# 171 南投_101_訴_231.txt
# 柒萬壹仟玖佰玖拾參
# 南投	南投_101_訴_231	民事判決	71993	True	[0, 0]
#
# 172 南投_101_訴_250.txt
# 南投	南投_101_訴_250	民事判決	0	False	[0, 0]
#
# 173 南投_101_訴_261.txt
# 壹拾捌萬零柒佰壹拾壹
# 南投	南投_101_訴_261	民事判決	180711	True	[0, [u'\u9673\u5efa\u52db\u5f8b\u5e2b', u'\u5f35\u7e7c\u6e96\u5f8b\u5e2b', u'\u838a\u60e0\u797a\u5f8b\u5e2b']]
#
# 174 南投_101_訴_28.txt
# 肆拾萬
# 南投	南投_101_訴_28	民事判決	400000	True	[[u'\u9ec3\u79c0\u862d\u5f8b\u5e2b'], 0]
#
# 175 南投_101_訴_291.txt
#
# 南投	南投_101_訴_291	民事判決	0	True	[0, 0]
#
# 176 南投_101_訴_298.txt
# 壹拾柒萬貳仟壹佰玖拾參
# 南投	南投_101_訴_298	民事判決	172193	True	[0, 0]
#
# 177 南投_101_訴_302.txt
# 捌萬玖仟柒佰伍拾肆
# 南投	南投_101_訴_302	民事判決	89754	True	[0, [u'\u738b\u58eb\u9298\u5f8b\u5e2b']]
#
# 178 南投_101_訴_303.txt
# 貳拾玖萬零伍佰肆拾壹
# 南投	南投_101_訴_303	民事判決	290541	True	[[u'\u674e\u9032\u5efa\u5f8b\u5e2b'], [u'\u738b\u58eb\u9298\u5f8b\u5e2b']]
#
# 179 南投_101_訴_308.txt
# 玖拾參萬伍仟貳佰伍拾參
# 南投	南投_101_訴_308	民事判決	935253	True	[0, [u'\u738b\u7389\u5982\u5f8b\u5e2b', u'\u8521\u9806\u5c45\u5f8b\u5e2b']]
#
# 180 南投_101_訴_312.txt
# 肆萬陸仟伍佰參拾
# 南投	南投_101_訴_312	民事判決	46530	True	[0, 0]
#
# 181 南投_101_訴_319.txt
# 肆萬零捌佰伍拾
# 南投	南投_101_訴_319	民事判決	40850	True	[0, 0]
#
# 182 南投_101_訴_385.txt
#
# 南投	南投_101_訴_385	民事判決	0	True	[0, [u'\u5f90\u76db\u570b\u5f8b\u5e2b']]
#
# 183 南投_101_訴_404.txt
# 肆拾伍萬零玖佰參拾
# 南投	南投_101_訴_404	民事判決	450930	True	[0, 0]
#
# 184 南投_101_訴_406.txt
# 捌拾柒萬肆仟肆佰柒拾
# 南投	南投_101_訴_406	民事判決	874470	True	[[u'\u6797\u9d6c\u8d8a\u5f8b\u5e2b'], [u'\u6797\u5951\u540d\u5f8b\u5e2b']]
#
# 185 南投_101_訴_410.txt
# 貳佰肆拾肆萬玖仟參佰肆拾肆
# 南投	南投_101_訴_410	民事判決	2449344	True	[[u'\u674e\u660e\u6d77\u5f8b\u5e2b', u'\u8a79\u5fd7\u5b8f\u5f8b\u5e2b'], [u'\u6797\u74ca\u5609\u5f8b\u5e2b']]
#
# 186 南投_101_訴_454.txt
# 貳拾壹萬零柒佰陸拾貳
# 南投	南投_101_訴_454	民事判決	210762	True	[0, 0]
#
# 187 南投_101_訴_458.txt
# 南投	南投_101_訴_458	民事判決	0	False	[[u'\u6e38\u7426\u4fca\u5f8b\u5e2b', u'\u738b\u6587\u8056\u5f8b\u5e2b'], [u'\u8a79\u6f22\u5c71\u5f8b\u5e2b', u'\u6c5f\u6977\u5f37\u5f8b\u5e2b']]
#
# 188 南投_101_訴_5.txt
# 南投	南投_101_訴_5	民事判決	0	False	[0, [u'\u5f35\u7e3e\u5bf6\u5f8b\u5e2b', u'\u8521\u5176\u9f8d\u5f8b\u5e2b', u'\u838a\u60e0\u797a\u5f8b\u5e2b\r']]
#
# 189 南投_101_訴_51.txt
# 壹佰零陸萬伍仟參佰參拾參
# 南投	南投_101_訴_51	民事判決	1065333	True	[0, 0]
#
# 190 南投_101_訴_73.txt
# 參佰伍拾伍萬陸仟貳佰零柒
# 南投	南投_101_訴_73	民事判決	3556207	True	[[u'\u85cd\u660e\u6d69\u5f8b\u5e2b'], [u'\u5289\u60e0\u5229\u5f8b\u5e2b']]
#
# 191 南投_101_訴_75.txt
# 壹佰零貳萬陸仟伍佰柒拾玖
# 南投	南投_101_訴_75	民事判決	1026579	True	[[u'\u7518\u9f8d\u5f37\u5f8b\u5e2b'], [u'\u674e\u5f8c\u653f\u5f8b\u5e2b']]
#
# 192 南投_101_訴_77.txt
# 南投	南投_101_訴_77	民事判決	0	False	[[u'\u6d82\u671d\u8208\u5f8b\u5e2b\r'], 0]
#
# 193 南投_101_訴_8.txt
# 陸萬
# 南投	南投_101_訴_8	民事判決	60000	True	[0, 0]
#
# 194 南投_101_醫_1.txt
# 南投	南投_101_醫_1	民事判決	0	False	[[u'\u9673\u76ca\u8ed2\u5f8b\u5e2b'], [u'\u5f35\u8c50\u5b88\u5f8b\u5e2b', u'\u5433\u8389\u9d26\u5f8b\u5e2b', u'\u5f8b\u5e2b\r']]
#
# 195 南投_101_重訴_20.txt
# 捌佰玖拾捌萬肆仟陸佰零伍
# 南投	南投_101_重訴_20	民事判決	8984605	True	[[u'\u8607\u986f\u8b80\u5f8b\u5e2b', u'\u66fe\u742c\u9234\u5f8b\u5e2b\r'], [u'\u6797\u74ca\u5609\u5f8b\u5e2b\r', u'\u7d00\u5cb3\u826f\u5f8b\u5e2b']]
#
# 196 南投_101_重訴_21.txt
# 壹佰肆拾玖萬捌仟玖佰壹拾伍
# 南投	南投_101_重訴_21	民事判決	1498915	True	[[u'\u738b\u8000\u8ce2\u5f8b\u5e2b', u'\u9673\u5efa\u52db\u5f8b\u5e2b'], 0]
#
# 197 南投_101_重訴_4.txt
# 貳佰捌拾柒萬玖仟貳佰貳拾柒
# 南投	南投_101_重訴_4	民事判決	2879227	True	[[u'\u8a31\u5bb6\u745c\u5f8b\u5e2b'], 0]
#
# 198 南投_101_重訴_45.txt
# 參拾壹萬肆仟肆佰
# 南投	南投_101_重訴_45	民事判決	314400	True	[0, 0]
#
# 199 南投_101_重訴_51.txt
# 捌拾捌萬伍仟柒佰參拾
# 南投	南投_101_重訴_51	民事判決	885730	True	[[u'\u9ad8\u9032\u68d6\u5f8b\u5e2b'], 0]
#
# 200 南投_101_重訴_69.txt
# 壹佰陸拾柒萬陸仟玖佰玖拾玖
# 南投	南投_101_重訴_69	民事判決	1676999	True	[0, 0]
#
# 201 南投_101_重訴_8.txt
# 肆佰肆拾伍萬貳仟玖佰陸拾伍
# 南投	南投_101_重訴_8	民事判決	4452965	True	[0, 0]
#
# 202 南投_102_勞訴_4.txt
# 壹拾柒萬捌仟玖佰陸拾柒
# 南投	南投_102_勞訴_4	民事判決	178967	True	[[u'\u9673\u4e16\u5ddd\u5f8b\u5e2b'], [u'\u5433\u8389\u9d26\u5f8b\u5e2b']]
#
# 203 南投_102_原埔小_1.txt
# 貳萬捌仟參佰肆拾柒
# 南投	南投_102_原埔小_1	民事小額判決	28347	True	[0, 0]
#
# 204 南投_102_原埔小_2.txt
# 參萬參仟捌佰拾貳
# 南投	南投_102_原埔小_2	民事小額判決	33802	True	[0, 0]
#
# 205 南投_102_原埔簡_3.txt
# 貳拾陸萬伍仟陸佰零捌
# 南投	南投_102_原埔簡_3	民事簡易判決	265608	True	[0, 0]
#
# 206 南投_102_原簡_1.txt
# 柒仟肆佰
# 南投	南投_102_原簡_1	民事簡易判決	7400	True	[0, 0]
#
# 207 南投_102_埔小_103.txt
# 壹萬柒仟貳佰陸拾壹
# 南投	南投_102_埔小_103	民事小額判決	17261	True	[0, 0]
#
# 208 南投_102_埔小_124.txt
# 玖仟零柒拾
# 南投	南投_102_埔小_124	民事小額判決	9070	True	[0, 0]
#
# 209 南投_102_埔小_131.txt
# 玖仟伍佰玖拾參
# 南投	南投_102_埔小_131	民事小額判決	9593	True	[0, 0]
#
# 210 南投_102_埔小_171.txt
#
# 南投	南投_102_埔小_171	民事小額判決	0	True	[0, 0]
#
# 211 南投_102_埔小_178.txt
# 伍仟肆佰玖拾伍
# 南投	南投_102_埔小_178	民事小額判決	5495	True	[0, 0]
#
# 212 南投_102_埔小_185.txt
# 南投	南投_102_埔小_185	民事小額判決	0	False	[0, 0]
#
# 213 南投_102_埔小_189.txt
# 壹萬
# 南投	南投_102_埔小_189	民事小額判決	10000	True	[0, 0]
#
# 214 南投_102_埔小_195.txt
# 參萬捌仟柒佰拾柒
# 南投	南投_102_埔小_195	民事小額判決	38707	True	[0, 0]
#
# 215 南投_102_埔小_55.txt
# 貳萬伍仟貳佰玖拾參
# 南投	南投_102_埔小_55	民事小額判決	25293	True	[0, 0]
#
# 216 南投_102_埔小_66.txt
# 伍萬參仟陸佰貳拾
# 南投	南投_102_埔小_66	民事小額判決	53620	True	[0, 0]
#
# 217 南投_102_埔小_75.txt
# 伍仟
# 南投	南投_102_埔小_75	民事小額判決	5000	True	[0, 0]
#
# 218 南投_102_埔小_82.txt
#
# 南投	南投_102_埔小_82	民事小額判決	0	True	[0, 0]
#
# 219 南投_102_埔小_94.txt
# 壹萬陸仟
# 南投	南投_102_埔小_94	民事小額判決	16000	True	[0, 0]
#
# 220 南投_102_埔小_97.txt
# 壹萬肆仟貳佰肆拾玖
# 南投	南投_102_埔小_97	民事小額判決	14249	True	[0, 0]
#
# 221 南投_102_埔小_98.txt
# 參萬捌仟陸佰肆拾柒
# 南投	南投_102_埔小_98	民事小額判決	38647	True	[0, 0]
#
# 222 南投_102_埔簡_123.txt
# 壹拾萬參仟壹佰肆拾參
# 南投	南投_102_埔簡_123	民事簡易判決	103143	True	[0, 0]
#
# 223 南投_102_埔簡_168.txt
# 壹萬玖仟柒佰零柒
# 南投	南投_102_埔簡_168	民事簡易判決	19707	True	[0, 0]
#
# 224 南投_102_埔簡_26.txt
# 玖萬壹仟參佰拾陸
# 南投	南投_102_埔簡_26	民事簡易判決	91306	True	[0, 0]
#
# 225 南投_102_埔簡_76.txt
# 拾貳萬零肆佰伍拾
# 南投	南投_102_埔簡_76	民事簡易判決	120450	True	[0, 0]
#
# 226 南投_102_埔簡_93.txt
# 貳拾貳萬肆仟壹佰陸拾參
# 南投	南投_102_埔簡_93	民事簡易判決	224163	True	[0, 0]
#
# 227 南投_102_投小_100.txt
# 壹萬玖仟柒佰柒拾
# 南投	南投_102_投小_100	民事小額判決	19770	True	[0, 0]
#
# 228 南投_102_投小_129.txt
# 肆萬零貳佰柒拾肆
# 南投	南投_102_投小_129	民事小額判決	40274	True	[0, 0]
#
# 229 南投_102_投小_14.txt
# 壹萬伍仟肆佰零捌
# 南投	南投_102_投小_14	民事小額判決	15408	True	[0, 0]
#
# 230 南投_102_投小_145.txt
# 貳萬陸仟參佰參拾參
# 南投	南投_102_投小_145	民事小額判決	26333	True	[0, 0]
#
# 231 南投_102_投小_17.txt
# 壹萬參仟參佰貳拾肆
# 南投	南投_102_投小_17	民事小額判決	13324	True	[0, 0]
#
# 232 南投_102_投小_170.txt
# 參萬陸仟玖佰零參
# 南投	南投_102_投小_170	民事小額判決	36903	True	[0, 0]
#
# 233 南投_102_投小_180.txt
# 柒仟壹佰伍拾捌
# 南投	南投_102_投小_180	民事小額判決	7158	True	[0, 0]
#
# 234 南投_102_投小_185.txt
# 貳萬參仟肆佰參拾肆
# 南投	南投_102_投小_185	民事小額判決	23434	True	[0, 0]
#
# 235 南投_102_投小_193.txt
# 參萬玖仟伍佰零參
# 南投	南投_102_投小_193	民事小額判決	39503	True	[0, 0]
#
# 236 南投_102_投小_201.txt
# 肆萬
# 南投	南投_102_投小_201	民事小額判決	40000	True	[0, 0]
#
# 237 南投_102_投小_225.txt
# 貳萬壹仟捌佰肆拾參
# 南投	南投_102_投小_225	民事小額判決	21843	True	[0, 0]
#
# 238 南投_102_投小_240.txt
# 貳萬零玖佰伍拾玖
# 南投	南投_102_投小_240	民事小額判決	20959	True	[0, 0]
#
# 239 南投_102_投小_248.txt
# 陸仟參佰肆拾壹
# 南投	南投_102_投小_248	民事小額判決	6341	True	[0, 0]
#
# 240 南投_102_投小_252.txt
# 壹萬肆仟陸佰肆拾玖
# 南投	南投_102_投小_252	民事小額判決	14649	True	[[u'\u738b\u58eb\u9298\u5f8b\u5e2b'], 0]
#
# 241 南投_102_投小_254.txt
# 貳萬肆仟伍佰伍拾陸
# 南投	南投_102_投小_254	民事小額判決	24556	True	[0, 0]
#
# 242 南投_102_投小_264.txt
# 壹佰伍拾玖
# 南投	南投_102_投小_264	民事小額判決	159	True	[0, 0]
#
# 243 南投_102_投小_284.txt
# 柒萬零玖佰玖拾柒
# 南投	南投_102_投小_284	民事小額判決	70997	True	[0, 0]
#
# 244 南投_102_投小_285.txt
# 陸仟零捌拾肆
# 南投	南投_102_投小_285	民事小額判決	6084	True	[0, 0]
#
# 245 南投_102_投小_305.txt
# 壹萬參仟玖佰陸拾捌
# 南投	南投_102_投小_305	民事小額判決	13968	True	[0, 0]
#
# 246 南投_102_投小_315.txt
# 貳萬壹仟參佰貳拾貳
# 南投	南投_102_投小_315	民事小額判決	21322	True	[0, 0]
#
# 247 南投_102_投小_323.txt
# 參萬伍仟
# 南投	南投_102_投小_323	民事小額判決	35000	True	[0, 0]
#
# 248 南投_102_投小_325.txt
# 參仟參佰壹拾參
# 南投	南投_102_投小_325	民事小額判決	3313	True	[0, 0]
#
# 249 南投_102_投小_344.txt
#
# 南投	南投_102_投小_344	民事小額判決	0	True	[0, 0]
#
# 250 南投_102_投小_350.txt
# 柒仟
# 南投	南投_102_投小_350	民事小額判決	7000	True	[0, 0]
#
# 251 南投_102_投小_375.txt
# 壹萬玖仟捌佰參拾參
# 南投	南投_102_投小_375	民事小額判決	19833	True	[0, 0]
#
# 252 南投_102_投小_424.txt
# 壹萬零陸佰肆拾柒
# 南投	南投_102_投小_424	民事小額判決	10647	True	[0, 0]
#
# 253 南投_102_投小_430.txt
# 參萬貳仟玖佰壹拾壹
# 南投	南投_102_投小_430	民事小額判決	32911	True	[0, 0]
#
# 254 南投_102_投小_461.txt
#
# 南投	南投_102_投小_461	民事小額判決	0	True	[0, 0]
#
# 255 南投_102_投小_472.txt
# 陸萬肆仟陸佰柒拾壹
# 南投	南投_102_投小_472	民事小額判決	64671	True	[0, 0]
#
# 256 南投_102_投小_473.txt
# 貳萬肆仟零捌
# 南投	南投_102_投小_473	民事小額判決	24008	True	[0, 0]
#
# 257 南投_102_投小_474.txt
# 參萬零柒佰肆拾伍
# 南投	南投_102_投小_474	民事小額判決	30745	True	[0, 0]
#
# 258 南投_102_投小_476.txt
# 捌仟貳佰伍拾玖
# 南投	南投_102_投小_476	民事小額判決	8259	True	[0, 0]
#
# 259 南投_102_投小_480.txt
# 伍萬
# 南投	南投_102_投小_480	民事小額判決	50000	True	[0, 0]
#
# 260 南投_102_投小_90.txt
# 玖仟陸佰柒拾肆
# 南投	南投_102_投小_90	民事小額判決	9674	True	[0, 0]
#
# 261 南投_102_投小_96.txt
# 參萬柒仟捌佰肆拾捌
# 南投	南投_102_投小_96	民事小額判決	37848	True	[0, 0]
#
# 262 南投_102_投簡_103.txt
# 壹拾貳萬陸仟伍佰陸拾壹
# 南投	南投_102_投簡_103	民事簡易判決	126561	True	[0, 0]
#
# 263 南投_102_投簡_131.txt
#
# 南投	南投_102_投簡_131	民事簡易判決	0	True	[0, 0]
#
# 264 南投_102_投簡_141.txt
# 貳拾貳萬零壹佰陸拾
# 南投	南投_102_投簡_141	民事簡易判決	220160	True	[0, 0]
#
# 265 南投_102_投簡_159.txt
# 陸萬玖仟貳佰玖拾柒
# 南投	南投_102_投簡_159	民事簡易判決	69297	True	[0, 0]
#
# 266 南投_102_投簡_193.txt
# 南投	南投_102_投簡_193	民事簡易判決	0	False	[0, 0]
#
# 267 南投_102_投簡_264.txt
# 拾萬
# 南投	南投_102_投簡_264	民事簡易判決	100000	True	[[u'\u6d2a\u5609\u9d3b\u5f8b\u5e2b', u'\u912d\u6643\u5947\u5f8b\u5e2b'], 0]
#
# 268 南投_102_投簡_272.txt
# 柒萬伍仟柒佰
# 南投	南投_102_投簡_272	民事簡易判決	75700	True	[0, 0]
#
# 269 南投_102_投簡_273.txt
# 南投	南投_102_投簡_273	民事簡易判決	0	False	[0, 0]
#
# 270 南投_102_投簡_28.txt
# 南投	南投_102_投簡_28	民事簡易判決	0	False	[0, 0]
#
# 271 南投_102_投簡_300.txt
# 壹拾玖萬陸仟玖佰零柒
# 南投	南投_102_投簡_300	民事簡易判決	196907	True	[[u'\u5433\u6600\u965e\u5f8b\u5e2b'], 0]
#
# 272 南投_102_投簡_341.txt
# 壹萬玖仟伍佰捌拾壹
# 南投	南投_102_投簡_341	民事簡易判決	19581	True	[0, 0]
#
# 273 南投_102_投簡_368.txt
# 拾萬捌仟伍佰拾壹
# 南投	南投_102_投簡_368	民事簡易判決	108501	True	[0, 0]
#
# 274 南投_102_投簡_383.txt
# 捌萬捌仟貳佰肆拾伍
# 南投	南投_102_投簡_383	民事簡易判決	88245	True	[0, 0]
#
# 275 南投_102_投簡_6.txt
# 南投	南投_102_投簡_6	民事簡易判決	0	False	[0, 0]
#
# 276 南投_102_投簡_76.txt
# 柒萬參仟伍佰貳拾陸
# 南投	南投_102_投簡_76	民事簡易判決	73526	True	[0, 0]
#
# 277 南投_102_簡_9.txt
# 肆拾萬柒仟零伍拾
# 南投	南投_102_簡_9	民事簡易判決	407050	True	[0, [u'\u738b\u58eb\u9298\u5f8b\u5e2b']]
#
# 278 南投_102_訴_103.txt
# 捌拾捌萬壹仟玖佰伍拾壹
# 南投	南投_102_訴_103	民事判決	881951	True	[[u'\u5289\u90a6\u9060\u5f8b\u5e2b'], [u'\u8607\u52dd\u5609\u5f8b\u5e2b\r']]
#
# 279 南投_102_訴_106.txt
# 壹佰伍拾伍萬參仟捌佰零陸
# 南投	南投_102_訴_106	民事判決	1553806	True	[[u'\u90b1\u6c38\u8c6a\u5f8b\u5e2b'], [u'\u8521\u5f97\u8b19\u5f8b\u5e2b', u'\u5f35\u5b8f\u9298\u5f8b\u5e2b', u'\u6c5f\u5065\u92d2\u5f8b\u5e2b\r']]
#
# 280 南投_102_訴_126.txt
# 壹佰陸拾貳萬肆仟捌佰玖拾
# 南投	南投_102_訴_126	民事判決	1624890	True	[[u'\u8a31\u667a\u6377\u5f8b\u5e2b'], [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b', u'\u8b1d\u5b8f\u5049\u5f8b\u5e2b']]
#
# 281 南投_102_訴_137.txt
# 壹佰陸拾捌萬參仟陸佰壹拾壹
# 南投	南投_102_訴_137	民事判決	1683611	True	[[u'\u694a\u535a\u4efb\u5f8b\u5e2b'], 0]
#
# 282 南投_102_訴_147.txt
# 南投	南投_102_訴_147	民事判決	0	False	[[u'\u5433\u5b9c\u661f\u5f8b\u5e2b', u'\u5433\u5b9c\u661f\u5f8b\u5e2b'], 0]
#
# 283 南投_102_訴_151.txt
# 壹拾柒萬參仟零陸拾伍
# 南投	南投_102_訴_151	民事判決	173065	True	[[u'\u5f90\u660e\u73e0\u5f8b\u5e2b'], 0]
#
# 284 南投_102_訴_159.txt
# 壹拾貳萬陸仟柒佰柒拾
# 南投	南投_102_訴_159	民事判決	126770	True	[0, 0]
#
# 285 南投_102_訴_162.txt
# 南投	南投_102_訴_162	民事判決	0	False	[[u'\u8521\u672c\u52c7\u5f8b\u5e2b', u'\u6d2a\u66c9\u83c1\u5f8b\u5e2b'], [u'\u5ed6\u5065\u667a\u5f8b\u5e2b', u'\u7d00\u80b2\u6cd3\u5f8b\u5e2b', u'\u937e\u739f\u7426\u5f8b\u5e2b\r']]
#
# 286 南投_102_訴_176.txt
# 參萬捌仟捌佰參拾柒
# 南投	南投_102_訴_176	民事判決	38837	True	[0, 0]
#
# 287 南投_102_訴_193.txt
# 柒拾陸萬肆仟柒佰捌拾陸
# 南投	南投_102_訴_193	民事判決	764786	True	[[u'\u9673\u5c45\u4eae\u5f8b\u5e2b'], [u'\u5433\u5149\u9678\u5f8b\u5e2b']]
#
# 288 南投_102_訴_195.txt
# 玖拾參萬捌仟參佰貳拾陸
# 南投	南投_102_訴_195	民事判決	938326	True	[0, 0]
#
# 289 南投_102_訴_196.txt
# 參拾萬
# 南投	南投_102_訴_196	民事判決	300000	True	[[u'\u5f35\u5d07\u54f2\u5f8b\u5e2b', u'\u5f35\u4ed5\u878d\u5f8b\u5e2b', u'\u912d\u5f18\u660e\u5f8b\u5e2b\r'], 0]
#
# 290 南投_102_訴_2.txt
# 壹拾玖萬參仟陸佰捌拾玖
# 南投	南投_102_訴_2	民事判決	193689	True	[0, 0]
#
# 291 南投_102_訴_218.txt
# 貳拾柒萬柒仟參佰貳拾壹
# 南投	南投_102_訴_218	民事判決	277321	True	[0, 0]
#
# 292 南投_102_訴_229.txt
# 伍拾柒萬伍仟貳佰伍拾貳
# 南投	南投_102_訴_229	民事判決	575252	True	[[u'\u694a\u8ed2\u5ef7\u5f8b\u5e2b'], 0]
#
# 293 南投_102_訴_24.txt
# 玖萬零貳佰參拾
# 南投	南投_102_訴_24	民事判決	90230	True	[0, 0]
#
# 294 南投_102_訴_25.txt
# 壹拾伍萬伍仟陸佰玖拾
# 南投	南投_102_訴_25	民事判決	155690	True	[[u'\u8521\u5176\u9f8d\u5f8b\u5e2b', u'\u9ec3\u5efa\u9594\u5f8b\u5e2b'], 0]
#
# 295 南投_102_訴_266.txt
# 壹佰玖拾伍萬零柒佰柒拾壹
# 南投	南投_102_訴_266	民事判決	1950771	True	[[u'\u5433\u6600\u965e\u5f8b\u5e2b'], [u'\u738b\u5ead\u9d3b\u5f8b\u5e2b']]
#
# 296 南投_102_訴_304.txt
# 壹拾捌萬捌仟玖佰壹拾陸
# 南投	南投_102_訴_304	民事判決	188916	True	[0, 0]
#
# 297 南投_102_訴_347.txt
# 柒萬貳仟柒佰肆拾
# 南投	南投_102_訴_347	民事判決	72740	True	[0, [u'\u8521\u5f97\u8b19\u5f8b\u5e2b', u'\u6c5f\u5065\u92d2\u5f8b\u5e2b\r']]
#
# 298 南投_102_訴_351.txt
# 陸拾貳萬零捌佰壹拾捌
# 南投	南投_102_訴_351	民事判決	620818	True	[0, 0]
#
# 299 南投_102_訴_352.txt
# 貳拾參萬柒仟伍佰零壹
# 南投	南投_102_訴_352	民事判決	237501	True	[0, 0]
#
# 300 南投_102_訴_355.txt
# 貳拾萬
# 南投	南投_102_訴_355	民事判決	200000	True	[0, 0]
#
# 301 南投_102_訴_381.txt
# 玖萬伍仟壹佰零肆
# 南投	南投_102_訴_381	民事判決	95104	True	[[u'\u8cf4\u9326\u6e90\u5f8b\u5e2b\r', u'\u738b\u58eb\u8c6a\u5f8b\u5e2b'], [u'\u738b\u671d\u748b\u5f8b\u5e2b']]
#
# 302 南投_102_訴_383.txt
# 壹拾貳萬貳仟柒佰零貳
# 南投	南投_102_訴_383	民事判決	122702	True	[0, 0]
#
# 303 南投_102_訴_42.txt
# 壹拾肆萬柒仟肆佰伍拾
# 南投	南投_102_訴_42	民事判決	147450	True	[0, 0]
#
# 304 南投_102_訴_489.txt
# 貳拾玖萬柒仟玖佰柒拾陸
# 南投	南投_102_訴_489	民事判決	297976	True	[[u'\u937e\u932b\u8cc7\u5f8b\u5e2b'], 0]
#
# 305 南投_102_訴_500.txt
# 壹拾萬
# 南投	南投_102_訴_500	民事判決	100000	True	[[u'\u7f85\u8c50\u80e4\u5f8b\u5e2b', u'\u8607\u975c\u6021\u5f8b\u5e2b\r'], [u'\u5f35\u570b\u6968\u5f8b\u5e2b']]
#
# 306 南投_102_訴_52.txt
# 貳拾貳萬參仟伍佰陸拾伍
# 南投	南投_102_訴_52	民事判決	223565	True	[[u'\u5433\u842c\u6625\u5f8b\u5e2b'], [u'\u85cd\u660e\u6d69\u5f8b\u5e2b']]
#
# 307 南投_102_醫_1.txt
# 南投	南投_102_醫_1	民事判決	0	False	[[u'\u674e\u5a49\u83ef\u5f8b\u5e2b'], [u'\u5433\u6893\u751f\u5f8b\u5e2b', u'\u5f35\u5b8f\u9298\u5f8b\u5e2b']]
#
# 308 南投_102_重訴_11.txt
# 貳佰柒拾萬柒仟零伍拾壹
# 南投	南投_102_重訴_11	民事判決	2707051	True	[[u'\u5f35\u5d07\u54f2\u5f8b\u5e2b', u'\u912d\u5f18\u660e\u5f8b\u5e2b', u'\u5f35\u4ed5\u878d\u5f8b\u5e2b\r'], [u'\u738b\u570b\u6cf0\u5f8b\u5e2b']]
#
# 309 南投_102_重訴_20.txt
# 伍佰捌拾萬
# 南投	南投_102_重訴_20	民事判決	5800000	True	[0, 0]
#
# 310 南投_102_重訴_35.txt
#
# 南投	南投_102_重訴_35	民事判決	0	True	[[u'\u5f35\u53f3\u4eba\u5f8b\u5e2b'], 0]
#
# 311 南投_102_重訴_49.txt
# 貳拾萬貳仟柒佰參拾陸
# 南投	南投_102_重訴_49	民事判決	202736	True	[0, 0]
#
# 312 南投_102_重訴_57.txt
# 壹佰貳拾肆萬玖仟玖佰壹拾陸
# 南投	南投_102_重訴_57	民事判決	1249916	True	[[u'\u912d\u5d07\u714c\u5f8b\u5e2b'], 0]
#
# 313 南投_102_重訴_72.txt
# 陸萬零參佰壹拾柒
# 南投	南投_102_重訴_72	民事判決	60317	True	[[u'\u5f35\u7e7c\u6e96\u5f8b\u5e2b', u'\u8521\u5176\u9f8d\u5f8b\u5e2b'], 0]
#
# 314 南投_102_重訴_80.txt
# 捌拾肆萬捌仟
# 南投	南投_102_重訴_80	民事判決	848000	True	[[u'\u8521\u9806\u5c45\u5f8b\u5e2b'], [u'\u9673\u76ca\u8ed2\u5f8b\u5e2b', u'\u9673\u5fd7\u9686\u5f8b\u5e2b']]
#
# 315 南投_103_原重訴_3.txt
# 參拾捌萬捌仟陸佰壹拾玖
# 南投	南投_103_原重訴_3	民事判決	388619	True	[[u'\u694a\u5fd7\u822a\u5f8b\u5e2b', u'\u694a\u5fd7\u822a\u5f8b\u5e2b'], [u'\u7f85\u8c50\u80e4\u5f8b\u5e2b', u'\u8607\u975c\u6021\u5f8b\u5e2b\r']]
#
# 316 南投_103_埔小_100.txt
# 陸仟伍佰壹拾參
# 南投	南投_103_埔小_100	民事小額判決	6513	True	[0, 0]
#
# 317 南投_103_埔小_102.txt
# 貳萬陸仟陸佰肆拾伍
# 南投	南投_103_埔小_102	民事小額判決	26645	True	[0, 0]
#
# 318 南投_103_埔小_144.txt
# 陸仟捌佰貳拾貳
# 南投	南投_103_埔小_144	民事小額判決	6822	True	[0, 0]
#
# 319 南投_103_埔小_149.txt
# 陸萬伍仟壹佰參拾
# 南投	南投_103_埔小_149	民事小額判決	65130	True	[0, 0]
#
# 320 南投_103_埔小_175.txt
# 壹萬伍仟零陸拾陸
# 南投	南投_103_埔小_175	民事小額判決	15066	True	[0, 0]
#
# 321 南投_103_埔小_179.txt
# 壹萬壹仟捌佰參拾壹
# 南投	南投_103_埔小_179	民事小額判決	11831	True	[0, 0]
#
# 322 南投_103_埔小_2.txt
# 壹萬參仟壹佰陸拾捌
# 南投	南投_103_埔小_2	民事小額判決	13168	True	[0, 0]
#
# 323 南投_103_埔小_208.txt
# 陸萬伍仟伍佰貳拾捌
# 南投	南投_103_埔小_208	民事小額判決	65528	True	[0, 0]
#
# 324 南投_103_埔小_209.txt
# 壹萬肆仟柒佰零捌
# 南投	南投_103_埔小_209	民事小額判決	14708	True	[0, 0]
#
# 325 南投_103_埔小_218.txt
# 南投	南投_103_埔小_218	民事小額判決	0	False	[0, 0]
#
# 326 南投_103_埔小_223.txt
# 肆萬陸仟捌佰參拾捌
# 南投	南投_103_埔小_223	民事小額判決	46838	True	[0, 0]
#
# 327 南投_103_埔小_224.txt
# 壹仟玖佰柒拾肆
# 南投	南投_103_埔小_224	民事小額判決	1974	True	[0, 0]
#
# 328 南投_103_埔小_35.txt
# 陸仟捌佰貳拾伍
# 南投	南投_103_埔小_35	民事小額判決	6825	True	[0, 0]
#
# 329 南投_103_埔小_41.txt
#
# 南投	南投_103_埔小_41	民事小額判決	0	True	[0, 0]
#
# 330 南投_103_埔小_42.txt
# 參仟柒佰玖拾壹
# 南投	南投_103_埔小_42	民事小額判決	3791	True	[0, 0]
#
# 331 南投_103_埔小_47.txt
# 參萬零伍佰零貳
# 南投	南投_103_埔小_47	民事小額判決	30502	True	[0, 0]
#
# 332 南投_103_埔小_52.txt
# 壹萬陸仟陸佰貳拾捌
# 南投	南投_103_埔小_52	民事小額判決	16628	True	[0, 0]
#
# 333 南投_103_埔小_56.txt
# 壹萬伍仟陸佰玖拾
# 南投	南投_103_埔小_56	民事小額判決	15690	True	[0, 0]
#
# 334 南投_103_埔小_66.txt
# 壹萬伍仟
# 南投	南投_103_埔小_66	民事小額判決	15000	True	[0, 0]
#
# 335 南投_103_埔小_89.txt
# 肆萬零肆佰參拾玖
# 南投	南投_103_埔小_89	民事小額判決	40439	True	[0, 0]
#
# 336 南投_103_埔小_90.txt
# 壹萬壹仟
# 南投	南投_103_埔小_90	民事小額判決	11000	True	[0, 0]
#
# 337 南投_103_埔小_96.txt
# 壹萬壹仟陸佰陸拾伍
# 南投	南投_103_埔小_96	民事小額判決	11665	True	[0, 0]
#
# 338 南投_103_埔簡_105.txt
# 伍萬壹仟參佰
# 南投	南投_103_埔簡_105	民事簡易判決	51300	True	[0, 0]
#
# 339 南投_103_埔簡_109.txt
# 伍萬壹仟貳佰零捌
# 南投	南投_103_埔簡_109	民事簡易判決	51208	True	[0, 0]
#
# 340 南投_103_埔簡_110.txt
# 貳拾貳萬零玖佰玖拾貳
# 南投	南投_103_埔簡_110	民事簡易判決	220992	True	[0, 0]
#
# 341 南投_103_埔簡_112.txt
# 南投	南投_103_埔簡_112	民事簡易判決	0	False	[0, 0]
#
# 342 南投_103_埔簡_133.txt
# 貳拾陸萬玖仟參佰參拾貳
# 南投	南投_103_埔簡_133	民事簡易判決	269332	True	[0, 0]
#
# 343 南投_103_埔簡_154.txt
# 參拾伍萬陸仟柒佰陸拾捌
# 南投	南投_103_埔簡_154	民事簡易判決	356768	True	[0, 0]
#
# 344 南投_103_埔簡_163.txt
# 貳萬零玖佰伍拾
# 南投	南投_103_埔簡_163	民事簡易判決	20950	True	[0, 0]
#
# 345 南投_103_埔簡_204.txt
# 參萬捌仟伍佰
# 南投	南投_103_埔簡_204	民事簡易判決	38500	True	[0, 0]
#
# 346 南投_103_埔簡_205.txt
# 壹拾陸萬肆仟捌佰零柒
# 南投	南投_103_埔簡_205	民事簡易判決	164807	True	[[u'\u6797\u5764\u8ce2\u5f8b\u5e2b'], 0]
#
# 347 南投_103_埔簡_42.txt
# 壹拾萬壹仟捌佰貳拾捌
# 南投	南投_103_埔簡_42	民事簡易判決	101828	True	[0, 0]
#
# 348 南投_103_埔簡_73.txt
# 參萬玖仟伍佰零捌
# 南投	南投_103_埔簡_73	民事簡易判決	39508	True	[0, 0]
#
# 349 南投_103_埔簡_78.txt
# 肆萬貳仟捌佰玖拾壹
# 南投	南投_103_埔簡_78	民事簡易判決	42891	True	[0, 0]
#
# 350 南投_103_埔簡_98.txt
# 壹拾貳萬伍仟
# 南投	南投_103_埔簡_98	民事簡易判決	125000	True	[0, 0]
#
# 351 南投_103_投小_123.txt
# 伍萬伍仟
# 南投	南投_103_投小_123	民事小額判決	55000	True	[0, 0]
#
# 352 南投_103_投小_125.txt
# 貳萬壹仟柒佰零參
# 南投	南投_103_投小_125	民事小額判決	21703	True	[0, 0]
#
# 353 南投_103_投小_136.txt
# 參萬壹仟肆佰壹拾
# 南投	南投_103_投小_136	民事小額判決	31410	True	[0, 0]
#
# 354 南投_103_投小_157.txt
# 伍仟玖佰貳拾
# 南投	南投_103_投小_157	民事小額判決	5920	True	[0, 0]
#
# 355 南投_103_投小_158.txt
# 壹萬壹仟壹佰柒拾肆
# 南投	南投_103_投小_158	民事小額判決	11174	True	[0, 0]
#
# 356 南投_103_投小_159.txt
# 參仟陸佰零參
# 南投	南投_103_投小_159	民事小額判決	3603	True	[0, 0]
#
# 357 南投_103_投小_161.txt
# 南投	南投_103_投小_161	民事小額判決	0	False	[0, 0]
#
# 358 南投_103_投小_162.txt
# 肆萬捌仟零玖拾貳
# 南投	南投_103_投小_162	民事小額判決	48092	True	[0, 0]
#
# 359 南投_103_投小_166.txt
# 參萬貳仟壹佰參拾壹
# 南投	南投_103_投小_166	民事小額判決	32131	True	[0, 0]
#
# 360 南投_103_投小_176.txt
# 柒萬壹仟零玖拾柒
# 南投	南投_103_投小_176	民事小額判決	71097	True	[0, 0]
#
# 361 南投_103_投小_184.txt
# 肆萬柒仟參佰捌拾陸
# 南投	南投_103_投小_184	民事小額判決	47386	True	[0, 0]
#
# 362 南投_103_投小_200.txt
# 壹萬柒仟玖佰柒拾肆
# 南投	南投_103_投小_200	民事小額判決	17974	True	[0, 0]
#
# 363 南投_103_投小_232.txt
# 伍萬參仟零壹拾柒
# 南投	南投_103_投小_232	民事小額判決	53017	True	[0, 0]
#
# 364 南投_103_投小_257.txt
# 參萬伍仟玖佰捌拾陸
# 南投	南投_103_投小_257	民事小額判決	35986	True	[0, 0]
#
# 365 南投_103_投小_258.txt
# 玖仟捌佰柒拾貳
# 南投	南投_103_投小_258	民事小額判決	9872	True	[0, 0]
#
# 366 南投_103_投小_262.txt
# 壹萬壹仟壹佰壹拾壹
# 南投	南投_103_投小_262	民事簡易判決	11111	True	[0, 0]
#
# 367 南投_103_投小_275.txt
# 貳萬捌仟零貳拾肆
# 南投	南投_103_投小_275	民事小額判決	28024	True	[0, 0]
#
# 368 南投_103_投小_315.txt
# 參仟
# 南投	南投_103_投小_315	民事小額判決	3000	True	[0, 0]
#
# 369 南投_103_投小_324.txt
# 陸仟玖佰
# 南投	南投_103_投小_324	民事小額判決	6900	True	[0, 0]
#
# 370 南投_103_投小_327.txt
# 肆仟肆佰捌拾伍
# 南投	南投_103_投小_327	民事小額判決	4485	True	[0, 0]
#
# 371 南投_103_投小_341.txt
# 壹萬壹仟陸佰伍拾伍
# 南投	南投_103_投小_341	民事小額判決	11655	True	[0, 0]
#
# 372 南投_103_投小_354.txt
# 柒仟壹佰肆拾壹
# 南投	南投_103_投小_354	民事小額判決	7141	True	[0, 0]
#
# 373 南投_103_投小_358.txt
# 壹萬貳仟肆佰貳拾捌
# 南投	南投_103_投小_358	民事小額判決	12428	True	[0, 0]
#
# 374 南投_103_投小_363.txt
# 壹萬捌仟柒佰玖拾伍
# 南投	南投_103_投小_363	民事小額判決	18795	True	[0, 0]
#
# 375 南投_103_投小_370.txt
# 壹萬貳仟陸佰貳拾捌
# 南投	南投_103_投小_370	民事小額判決	12628	True	[0, 0]
#
# 376 南投_103_投小_383.txt
# 玖仟柒佰伍拾捌
# 南投	南投_103_投小_383	民事小額判決	9758	True	[0, 0]
#
# 377 南投_103_投小_400.txt
# 壹萬玖仟零壹
# 南投	南投_103_投小_400	民事小額判決	19001	True	[0, 0]
#
# 378 南投_103_投小_412.txt
# 參萬貳仟捌佰捌拾貳
# 南投	南投_103_投小_412	民事小額判決	32882	True	[0, 0]
#
# 379 南投_103_投小_418.txt
# 參萬壹仟陸佰壹拾
# 南投	南投_103_投小_418	民事簡易判決	31610	True	[0, 0]
#
# 380 南投_103_投小_43.txt
# 壹萬肆仟零貳拾
# 南投	南投_103_投小_43	民事小額判決	14020	True	[0, 0]
#
# 381 南投_103_投小_434.txt
# 壹萬捌仟參佰
# 南投	南投_103_投小_434	民事簡易判決	18300	True	[0, 0]
#
# 382 南投_103_投小_445.txt
# 陸仟參佰玖拾捌
# 南投	南投_103_投小_445	民事小額判決	6398	True	[0, 0]
#
# 383 南投_103_投小_465.txt
# 參萬陸仟玖佰拾玖
# 南投	南投_103_投小_465	民事小額判決	36909	True	[0, 0]
#
# 384 南投_103_投小_479.txt
# 玖仟零伍拾肆
# 南投	南投_103_投小_479	民事簡易判決	9054	True	[0, 0]
#
# 385 南投_103_投小_494.txt
# 壹萬零肆佰玖拾伍
# 南投	南投_103_投小_494	民事小額判決	10495	True	[0, 0]
#
# 386 南投_103_投小_503.txt
# 壹萬零柒佰捌拾肆
# 南投	南投_103_投小_503	民事小額判決	10784	True	[0, 0]
#
# 387 南投_103_投小_512.txt
# 參萬捌仟參佰零伍
# 南投	南投_103_投小_512	民事小額判決	38305	True	[0, 0]
#
# 388 南投_103_投小_533.txt
# 壹萬柒仟陸佰伍拾
# 南投	南投_103_投小_533	民事小額判決	17650	True	[0, 0]
#
# 389 南投_103_投小_534.txt
# 參萬陸仟參佰玖拾壹
# 南投	南投_103_投小_534	民事小額判決	36391	True	[0, 0]
#
# 390 南投_103_投小_536.txt
# 參萬貳仟肆佰貳拾玖
# 南投	南投_103_投小_536	民事小額判決	32429	True	[0, 0]
#
# 391 南投_103_投小_544.txt
# 壹萬柒仟玖佰壹拾壹
# 南投	南投_103_投小_544	民事小額判決	17911	True	[0, 0]
#
# 392 南投_103_投小_60.txt
# 陸佰柒拾玖
# 南投	南投_103_投小_60	民事小額判決	679	True	[0, 0]
#
# 393 南投_103_投小_87.txt
# 壹萬陸仟陸佰
# 南投	南投_103_投小_87	民事小額判決	16600	True	[0, 0]
#
# 394 南投_103_投簡_102.txt
# 參拾貳萬玖仟肆佰伍拾參
# 南投	南投_103_投簡_102	民事簡易判決	329453	True	[0, 0]
#
# 395 南投_103_投簡_111.txt
# 陸萬
# 南投	南投_103_投簡_111	民事簡易判決	60000	True	[0, 0]
#
# 396 南投_103_投簡_121.txt
# 玖萬貳仟柒佰參拾玖
# 南投	南投_103_投簡_121	民事簡易判決	92739	True	[0, 0]
#
# 397 南投_103_投簡_13.txt
# 壹拾肆萬捌仟柒佰零壹
# 南投	南投_103_投簡_13	民事簡易判決	148701	True	[0, 0]
#
# 398 南投_103_投簡_144.txt
#
# 南投	南投_103_投簡_144	民事簡易判決	0	True	[0, 0]
#
# 399 南投_103_投簡_145.txt
# 貳拾捌萬參仟伍佰肆拾柒
# 南投	南投_103_投簡_145	民事簡易判決	283547	True	[0, 0]
#
# 400 南投_103_投簡_181.txt
# 玖萬零陸佰
# 南投	南投_103_投簡_181	民事簡易判決	90600	True	[0, 0]
#
# 401 南投_103_投簡_186.txt
# 柒萬柒仟肆佰貳拾
# 南投	南投_103_投簡_186	民事簡易判決	77420	True	[0, 0]
#
# 402 南投_103_投簡_188.txt
# 捌萬壹仟肆佰參拾陸
# 南投	南投_103_投簡_188	民事簡易判決	81436	True	[0, 0]
#
# 403 南投_103_投簡_193.txt
# 伍萬參仟參佰陸拾
# 南投	南投_103_投簡_193	民事簡易判決	53360	True	[0, 0]
#
# 404 南投_103_投簡_196.txt
# 肆萬玖仟陸佰柒拾陸
# 南投	南投_103_投簡_196	民事簡易判決	49676	True	[0, 0]
#
# 405 南投_103_投簡_205.txt
# 壹拾伍萬
# 南投	南投_103_投簡_205	民事簡易判決	150000	True	[0, 0]
#
# 406 南投_103_投簡_230.txt
# 玖萬壹仟捌佰壹拾肆
# 南投	南投_103_投簡_230	民事簡易判決	91814	True	[0, 0]
#
# 407 南投_103_投簡_231.txt
# 貳萬貳仟捌佰肆拾貳
# 南投	南投_103_投簡_231	民事簡易判決	22842	True	[0, 0]
#
# 408 南投_103_投簡_241.txt
# 參萬
# 南投	南投_103_投簡_241	民事簡易判決	30000	True	[0, 0]
#
# 409 南投_103_投簡_246.txt
# 壹萬陸仟
# 南投	南投_103_投簡_246	民事簡易判決	16000	True	[0, 0]
#
# 410 南投_103_投簡_247.txt
# 南投	南投_103_投簡_247	民事簡易判決	0	False	[0, [u'\u8607\u52dd\u5609\u5f8b\u5e2b']]
#
# 411 南投_103_投簡_267.txt
# 壹拾肆萬參仟伍佰參拾
# 南投	南投_103_投簡_267	民事簡易判決	143530	True	[0, 0]
#
# 412 南投_103_投簡_31.txt
# 參拾壹萬參仟柒佰陸拾肆
# 南投	南投_103_投簡_31	民事簡易判決	313764	True	[0, 0]
#
# 413 南投_103_投簡_310.txt
# 伍萬玖仟捌佰玖拾伍
# 南投	南投_103_投簡_310	民事簡易判決	59895	True	[0, 0]
#
# 414 南投_103_投簡_393.txt
# 壹萬零玖佰零捌
# 南投	南投_103_投簡_393	民事簡易判決	10908	True	[0, 0]
#
# 415 南投_103_投簡_394.txt
# 柒萬
# 南投	南投_103_投簡_394	民事簡易判決	70000	True	[0, 0]
#
# 416 南投_103_投簡_401.txt
# 南投	南投_103_投簡_401	民事簡易判決	0	False	[0, 0]
#
# 417 南投_103_投簡_407.txt
# 壹拾捌萬玖仟陸佰柒拾
# 南投	南投_103_投簡_407	民事簡易判決	189670	True	[0, 0]
#
# 418 南投_103_投簡_414.txt
# 南投	南投_103_投簡_414	民事簡易判決	0	False	[0, 0]
#
# 419 南投_103_投簡_418.txt
# 新臺幣壹拾肆萬捌仟玖佰玖拾捌
# 南投	南投_103_投簡_418	民事簡易判決	0	True	[0, 0]
#
# 420 南投_103_投簡_42.txt
# 貳萬參仟壹佰肆拾參
# 南投	南投_103_投簡_42	民事簡易判決	23143	True	[0, 0]
#
# 421 南投_103_投簡_459.txt
# 壹拾捌萬參仟零陸拾玖
# 南投	南投_103_投簡_459	民事簡易判決	183069	True	[0, 0]
#
# 422 南投_103_投簡_463.txt
# 柒萬伍仟伍佰伍拾伍
# 南投	南投_103_投簡_463	民事簡易判決	75555	True	[0, 0]
#
# 423 南投_103_投簡_464.txt
# 壹拾參萬零陸佰肆拾貳
# 南投	南投_103_投簡_464	民事簡易判決	130642	True	[0, 0]
#
# 424 南投_103_投簡_468.txt
# 捌萬參仟伍佰柒拾陸
# 南投	南投_103_投簡_468	民事簡易判決	83576	True	[0, 0]
#
# 425 南投_103_投簡_469.txt
# 參萬壹仟
# 南投	南投_103_投簡_469	民事簡易判決	31000	True	[[u'\u694a\u5fd7\u822a\u5f8b\u5e2b'], 0]
#
# 426 南投_103_投簡_74.txt
# 玖萬玖仟壹佰陸拾
# 南投	南投_103_投簡_74	民事簡易判決	99160	True	[0, 0]
#
# 427 南投_103_投簡_77.txt
# 伍萬
# 南投	南投_103_投簡_77	民事簡易判決	50000	True	[0, 0]
#
# 428 南投_103_投簡_79.txt
# 南投	南投_103_投簡_79	民事簡易判決	0	False	[0, 0]
#
# 429 南投_103_投簡_83.txt
# 柒萬貳仟壹佰壹拾
# 南投	南投_103_投簡_83	民事簡易判決	72110	True	[0, 0]
#
# 430 南投_103_投簡_97.txt
# 參萬伍仟玖佰肆拾貳
# 南投	南投_103_投簡_97	民事簡易判決	35942	True	[0, 0]
#
# 431 南投_103_訴_138.txt
# 伍萬柒仟壹佰柒拾柒
# 南投	南投_103_訴_138	民事判決	57177	True	[[u'\u9673\u6c86\u6cb3\u5f8b\u5e2b'], 0]
#
# 432 南投_103_訴_160.txt
# 肆拾貳萬
# 南投	南投_103_訴_160	民事判決	420000	True	[0, 0]
#
# 433 南投_103_訴_197.txt
# 壹拾萬陸仟壹佰捌拾玖
# 南投	南投_103_訴_197	民事判決	106189	True	[0, 0]
#
# 434 南投_103_訴_198.txt
# 壹拾壹萬柒仟肆佰貳拾柒
# 南投	南投_103_訴_198	民事判決	117427	True	[[u'\u7c21\u7965\u7d0b\u5f8b\u5e2b', u'\u8a31\u5b9c\u5afa\u5f8b\u5e2b'], [u'\u6731\u6587\u8ca1\u5f8b\u5e2b']]
#
# 435 南投_103_訴_215.txt
# 陸拾陸萬壹仟捌佰陸拾肆
# 南投	南投_103_訴_215	民事判決	661864	True	[0, 0]
#
# 436 南投_103_訴_220.txt
# 肆拾壹萬壹仟參佰參拾貳
# 南投	南投_103_訴_220	民事判決	411332	True	[0, 0]
#
# 437 南投_103_訴_234.txt
# 壹拾陸萬肆仟柒佰柒拾玖
# 南投	南投_103_訴_234	民事判決	164779	True	[[u'\u5442\u79c0\u6885\u5f8b\u5e2b\r'], 0]
#
# 438 南投_103_訴_26.txt
# 伍萬零壹佰玖拾玖
# 南投	南投_103_訴_26	民事判決	50199	True	[[u'\u738b\u6587\u8056\u5f8b\u5e2b'], 0]
#
# 439 南投_103_訴_263.txt
# 陸萬零捌佰陸拾參
# 南投	南投_103_訴_263	民事判決	60863	True	[0, [u'\u5f35\u7e3e\u5bf6\u5f8b\u5e2b', u'\u838a\u60e0\u797a\u5f8b\u5e2b', u'\u9673\u5f65\u4ef7\u5f8b\u5e2b\r']]
#
# 440 南投_103_訴_265.txt
# 柒拾壹萬壹仟捌佰壹拾玖
# 南投	南投_103_訴_265	民事判決	711819	True	[0, 0]
#
# 441 南投_103_訴_284.txt
# 柒拾萬零柒佰參拾貳
# 南投	南投_103_訴_284	民事判決	700732	True	[0, [u'\u5f90\u66c9\u840d\u5f8b\u5e2b']]
#
# 442 南投_103_訴_308.txt
# 南投	南投_103_訴_308	民事判決	0	False	[0, [u'\u6797\u842c\u751f\u5f8b\u5e2b', u'\u738b\u58eb\u8c6a\u5f8b\u5e2b']]
#
# 443 南投_103_訴_312.txt
# 伍拾玖萬肆仟貳佰捌拾肆
# 南投	南投_103_訴_312	民事判決	594284	True	[[u'\u5289\u90a6\u9060\u5f8b\u5e2b'], [u'\u912d\u5f18\u660e\u5f8b\u5e2b']]
#
# 444 南投_103_訴_40.txt
# 壹拾陸萬肆仟柒佰肆拾伍
# 南投	南投_103_訴_40	民事判決	164745	True	[0, 0]
#
# 445 南投_103_訴_402.txt
# 參拾陸萬壹仟貳佰貳拾玖
# 南投	南投_103_訴_402	民事判決	361229	True	[0, 0]
#
# 446 南投_103_訴_53.txt
# 陸拾捌萬貳仟肆佰柒拾伍
# 南投	南投_103_訴_53	民事判決	682475	True	[0, 0]
#
# 447 南投_103_訴_6.txt
# 肆拾玖萬伍仟玖佰參拾柒
# 南投	南投_103_訴_6	民事判決	495937	True	[0, 0]
#
# 448 南投_103_訴_66.txt
# 南投	南投_103_訴_66	民事判決	0	False	[0, 0]
#
# 449 南投_103_訴_94.txt
# 壹仟肆佰陸拾參
# 南投	南投_103_訴_94	民事判決	1463	True	[[u'\u738b\u5fe0\u6c82\u5f8b\u5e2b'], [u'\u66fe\u742c\u9234\u5f8b\u5e2b']]
#
# 450 南投_103_重訴_4.txt
# 肆拾捌萬柒仟柒佰肆拾肆
# 南投	南投_103_重訴_4	民事判決	487744	True	[0, 0]
#
# 451 南投_103_重訴_43.txt
# 壹佰零伍萬玖仟伍佰陸拾壹
# 南投	南投_103_重訴_43	民事判決	1059561	True	[[u'\u5289\u90a6\u9060\u5f8b\u5e2b'], [u'\u8607\u52dd\u5609\u5f8b\u5e2b']]
#
# 452 南投_103_重訴_45.txt
#
# 南投	南投_103_重訴_45	民事判決	0	True	[0, 0]
#
# 453 南投_103_重訴_5.txt
# 肆佰參拾壹萬貳仟參佰伍拾貳
# 南投	南投_103_重訴_5	民事判決	4312352	True	[[u'\u5433\u5149\u9678\u5f8b\u5e2b', u'\u5433\u5149\u9678\u5f8b\u5e2b'], [u'\u5433\u69ae\u660c\u5f8b\u5e2b', u'\u912d\u4e2d\u777f\u5f8b\u5e2b']]
#
# 454 南投_103_重訴_57.txt
# 參佰玖拾玖萬玖佰貳拾參
# 南投	南投_103_重訴_57	民事判決	3990923	True	[[u'\u5442\u52dd\u8ce2\u5f8b\u5e2b'], 0]
#
# 455 南投_104_埔小_1.txt
# 捌仟伍佰參拾陸
# 南投	南投_104_埔小_1	民事小額判決	8536	True	[0, 0]
#
# 456 南投_104_埔小_11.txt
# 伍仟柒佰肆拾陸
# 南投	南投_104_埔小_11	民事小額判決	5746	True	[0, 0]
#
# 457 南投_104_埔小_33.txt
# 貳萬捌仟參佰陸拾壹
# 南投	南投_104_埔小_33	民事小額判決	28361	True	[0, 0]
#
# 458 南投_104_埔小_34.txt
# 貳仟參佰零壹
# 南投	南投_104_埔小_34	民事小額判決	2301	True	[0, 0]
#
# 459 南投_104_埔小_36.txt
# 參萬肆仟零伍拾陸
# 南投	南投_104_埔小_36	民事小額判決	34056	True	[0, 0]
#
# 460 南投_104_埔小_42.txt
# 貳萬參仟貳佰伍拾柒
# 南投	南投_104_埔小_42	民事小額判決	23257	True	[0, 0]
#
# 461 南投_104_埔小_6.txt
# 參仟捌佰柒拾玖
# 南投	南投_104_埔小_6	民事小額判決	3879	True	[0, 0]
#
# 462 南投_104_埔簡_14.txt
# 伍萬零肆佰貳拾參
# 南投	南投_104_埔簡_14	民事簡易判決	50423	True	[0, 0]
#
# 463 南投_104_埔簡_2.txt
# 柒萬
# 南投	南投_104_埔簡_2	民事簡易判決	70000	True	[0, 0]
#
# 464 南投_104_埔簡_38.txt
# 伍萬貳仟肆佰伍拾
# 南投	南投_104_埔簡_38	民事簡易判決	52450	True	[0, 0]
#
# 465 南投_104_埔簡_4.txt
# 肆萬柒仟陸佰柒拾捌
# 南投	南投_104_埔簡_4	民事簡易判決	47678	True	[0, 0]
#
# 466 南投_104_投小_1.txt
# 貳萬肆仟捌佰參拾貳
# 南投	南投_104_投小_1	民事小額判決	24832	True	[0, 0]
#
# 467 南投_104_投小_107.txt
# 南投	南投_104_投小_107	民事小額判決	0	False	[0, 0]
#
# 468 南投_104_投小_11.txt
# 肆萬貳仟玖佰陸拾
# 南投	南投_104_投小_11	民事小額判決	42960	True	[0, 0]
#
# 469 南投_104_投小_112.txt
# 壹萬伍仟柒佰捌拾壹
# 南投	南投_104_投小_112	民事小額判決	15781	True	[0, 0]
#
# 470 南投_104_投小_116.txt
# 玖仟玖佰柒拾伍
# 南投	南投_104_投小_116	民事小額判決	9975	True	[0, 0]
#
# 471 南投_104_投小_26.txt
# 壹萬捌仟零柒拾壹
# 南投	南投_104_投小_26	民事小額判決	18071	True	[0, 0]
#
# 472 南投_104_投小_28.txt
# 壹萬零玖拾捌
# 南投	南投_104_投小_28	民事小額判決	10098	True	[0, 0]
#
# 473 南投_104_投小_50.txt
# 肆萬參仟貳佰參拾柒
# 南投	南投_104_投小_50	民事小額判決	43237	True	[0, 0]
#
# 474 南投_104_投小_85.txt
# 壹萬貳仟參佰壹拾參
# 南投	南投_104_投小_85	民事小額判決	12313	True	[0, 0]
#
# 475 南投_104_投小_86.txt
# 壹萬參仟零玖拾肆
# 南投	南投_104_投小_86	民事小額判決	13094	True	[0, 0]
#
# 476 南投_104_投小_88.txt
# 壹萬玖仟參佰玖拾參
# 南投	南投_104_投小_88	民事小額判決	19393	True	[0, 0]
#
# 477 南投_104_投小_89.txt
# 玖仟肆佰捌拾陸
# 南投	南投_104_投小_89	民事小額判決	9486	True	[0, 0]
#
# 478 南投_104_投小_90.txt
# 壹萬柒仟陸佰肆拾壹
# 南投	南投_104_投小_90	民事簡易判決	17641	True	[0, 0]
#
# 479 南投_104_投小_91.txt
# 壹萬柒仟玖佰壹拾玖
# 南投	南投_104_投小_91	民事小額判決	17919	True	[0, 0]
#
# 480 南投_104_投簡_103.txt
# 貳萬壹仟參佰柒拾壹
# 南投	南投_104_投簡_103	民事簡易判決	21371	True	[0, 0]
#
# 481 南投_104_投簡_123.txt
# 壹萬貳仟捌佰壹拾
# 南投	南投_104_投簡_123	民事簡易判決	12810	True	[0, 0]
#
# 482 南投_104_投簡_15.txt
# 陸萬零玖佰伍拾伍
# 南投	南投_104_投簡_15	民事簡易判決	60955	True	[0, 0]
#
# 483 南投_104_投簡_27.txt
# 南投	南投_104_投簡_27	民事簡易判決	0	False	[0, 0]
#
# 484 南投_104_投簡_44.txt
# 南投	南投_104_投簡_44	民事簡易判決	0	False	[0, 0]
#
# 485 南投_104_投簡_46.txt
# 參萬零伍佰伍拾陸
# 南投	南投_104_投簡_46	民事簡易判決	30556	True	[0, 0]
#
# 486 南投_104_投簡_62.txt
# 肆萬貳仟捌佰玖拾壹
# 南投	南投_104_投簡_62	民事簡易判決	42891	True	[0, 0]
#
# 487 南投_104_投簡_79.txt
#
# 南投	南投_104_投簡_79	民事簡易判決	0	True	[0, 0]
#
# 488 南投_104_投簡_82.txt
# 肆拾捌萬參仟捌佰玖拾伍
# 南投	南投_104_投簡_82	民事簡易判決	483895	True	[[u'\u9673\u6587\u6167\u5f8b\u5e2b'], 0]
#
# 489 南投_104_投簡_84.txt
# 壹拾捌萬柒仟伍佰貳拾參
# 南投	南投_104_投簡_84	民事簡易判決	187523	True	[0, 0]
#
# 490 南投_104_訴_93.txt
# 貳佰柒拾玖萬玖仟捌佰玖拾
# 南投	南投_104_訴_93	民事判決	2799890	True	[0, 0]
#
# 491 南投_87_訴_445.txt
# 肆拾壹萬肆仟肆佰柒拾捌
# 南投	南投_87_訴_445	民事判決	414478	True	[[u'\u8521\u9806\u5c45\u5f8b\u5e2b'], 0]
#
# 492 南投_88_訴_349.txt
#
# 南投	南投_88_訴_349	民事判決	0	True	[[u'\u8607\u4fca\u7dad\u5f8b\u5e2b'], [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b']]
#
# 493 南投_88_訴_404.txt
# 貳佰肆拾壹萬零肆佰壹拾伍
# 南投	南投_88_訴_404	民事判決	2410415	True	[0, 0]
#
# 494 南投_88_訴_407.txt
# 參拾陸萬陸仟零柒拾
# 南投	南投_88_訴_407	民事判決	366070	True	[0, 0]
#
# 495 南投_88_訴_420.txt
# 貳拾玖萬柒仟玖佰參拾玖
# 南投	南投_88_訴_420	民事判決	297939	True	[0, 0]
#
# 496 南投_88_訴_448.txt
# 貳拾萬捌仟壹佰零貳
# 南投	南投_88_訴_448	民事判決	208102	True	[0, 0]
#
# 497 南投_88_訴_451.txt
# 伍拾捌萬零肆佰貳拾伍
# 南投	南投_88_訴_451	民事判決	580425	True	[0, 0]
#
# 498 南投_88_訴_456.txt
# 拾柒萬陸仟捌佰參拾貳
# 南投	南投_88_訴_456	民事判決	176832	True	[[u'\u5b6b\u660e\u714c\u5f8b\u5e2b'], 0]
#
# 499 南投_88_訴_481.txt
# 肆拾柒萬柒仟壹佰柒拾捌
# 南投	南投_88_訴_481	民事判決	477178	True	[0, 0]
#
# 500 南投_88_訴_520.txt
# 肆拾玖萬陸仟零壹拾捌
# 南投	南投_88_訴_520	民事判決	496018	True	[0, 0]
#
# 501 南投_88_訴_539.txt
# 貳拾壹萬伍仟零貳拾伍
# 南投	南投_88_訴_539	民事判決	215025	True	[[u'\u5b6b\u660e\u714c\u5f8b\u5e2b'], 0]
#
# 502 南投_88_訴_542.txt
# 伍拾肆萬柒仟貳佰玖拾伍
# 南投	南投_88_訴_542	民事判決	547295	True	[[u'\u8521\u9806\u5c45\u5f8b\u5e2b', u'\u8cf4\u601d\u9054\u5f8b\u5e2b'], 0]
#
# 503 南投_88_訴_552.txt
# 柒拾參萬參仟參佰壹拾柒
# 南投	南投_88_訴_552	民事判決	733317	True	[0, 0]
#
# 504 南投_88_重訴_105.txt
# 壹仟玖佰捌拾玖萬零捌佰參拾參
# 南投	南投_88_重訴_105	民事判決	19890833	True	[[u'\u8521\u5b8f\u9686\u5f8b\u5e2b'], [u'\u5f35\u80b2\u8aa0\u5f8b\u5e2b']]
#
# 505 南投_89_訴_11.txt
# 壹拾伍萬玖仟陸佰貳拾柒
# 南投	南投_89_訴_11	民事判決	159627	True	[[u'\u9ec3\u6e05\u6c60\u5f8b\u5e2b'], [u'\u6797\u5fd7\u5fe0\u5f8b\u5e2b', u'\u5433\u745e\u582f\u5f8b\u5e2b\r', u'\u9673\u570b\u83ef\u5f8b\u5e2b']]
#
# 506 南投_89_訴_136.txt
# 南投	南投_89_訴_136	民事判決	0	False	[0, 0]
#
# 507 南投_89_訴_168.txt
# 壹拾陸萬柒仟陸佰參拾
# 南投	南投_89_訴_168	民事判決	167630	True	[0, 0]
#
# 508 南投_89_訴_169.txt
# 伍仟玖佰陸拾
# 南投	南投_89_訴_169	民事判決	5960	True	[0, 0]
#
# 509 南投_89_訴_174.txt
# 南投	南投_89_訴_174	民事判決	0	False	[0, 0]
#
# 510 南投_89_訴_180.txt
# 壹拾肆萬貳仟
# 南投	南投_89_訴_180	民事判決	142000	True	[0, 0]
#
# 511 南投_89_訴_186.txt
# 貳拾伍萬伍仟零柒
# 南投	南投_89_訴_186	民事判決	255007	True	[[u'\u5f35\u67cf\u5c71\u5f8b\u5e2b'], [u'\u6797\u90a6\u8ce2\u5f8b\u5e2b']]
#
# 512 南投_89_訴_199.txt
# 南投	南投_89_訴_199	民事判決	0	False	[0, 0]
#
# 513 南投_89_訴_201.txt
# 拾柒萬肆仟玖佰柒拾
# 南投	南投_89_訴_201	民事判決	174970	True	[0, 0]
#
# 514 南投_89_訴_221.txt
# 貳拾貳萬玖仟柒佰拾捌
# 南投	南投_89_訴_221	民事判決	229708	True	[[u'\u694a\u76ca\u677e\u5f8b\u5e2b'], 0]
#
# 515 南投_89_訴_265.txt
# 柒拾壹萬伍仟肆佰伍拾
# 南投	南投_89_訴_265	民事判決	715450	True	[[u'\u9673\u6b66\u748b\u5f8b\u5e2b', u'\u5ed6\u6842\u6b23\u5f8b\u5e2b'], 0]
#
# 516 南投_89_訴_267.txt
# 壹佰零伍萬
# 南投	南投_89_訴_267	民事判決	1050000	True	[0, 0]
#
# 517 南投_89_訴_268.txt
# 參拾肆萬貳仟捌佰柒拾
# 南投	南投_89_訴_268	民事判決	342870	True	[0, 0]
#
# 518 南投_89_訴_311.txt
# 壹佰零捌萬參仟柒佰伍拾貳
# 南投	南投_89_訴_311	民事判決	1083752	True	[0, 0]
#
# 519 南投_89_訴_312.txt
# 貳拾陸萬參仟貳佰伍拾壹
# 南投	南投_89_訴_312	民事判決	263251	True	[[u'\u856d\u6176\u8ce2\u5f8b\u5e2b'], [u'\u5289\u4f73\u7530\u5f8b\u5e2b']]
#
# 520 南投_89_訴_320.txt
# 壹拾貳萬壹仟
# 南投	南投_89_訴_320	民事判決	121000	True	[[u'\u5e9a\u25cb\u25cb\u5f8b\u5e2b', u'\u5e9a\u25cb\u25cb\u5f8b\u5e2b'], 0]
#
# 521 南投_89_訴_353.txt
# 捌拾壹萬陸仟壹佰零陸
# 南投	南投_89_訴_353	民事判決	816106	True	[[u'\u7530\u79ae\u5609\u5f8b\u5e2b'], [u'\u8cf4\u601d\u9054\u5f8b\u5e2b']]
#
# 522 南投_89_訴_355.txt
# 肆拾肆萬壹仟捌佰肆拾
# 南投	南投_89_訴_355	民事判決	441840	True	[[u'\u5f35\u67cf\u5c71\u5f8b\u5e2b', u'\u5f35\u67cf\u5c71\u5f8b\u5e2b'], 0]
#
# 523 南投_89_訴_363.txt
# 壹拾伍萬零玖佰柒拾捌
# 南投	南投_89_訴_363	民事判決	150978	True	[0, [u'\u6731\u6587\u8ca1\u5f8b\u5e2b', u'\u5b54\u6176\u5fe0\u5f8b\u5e2b']]
#
# 524 南投_89_訴_382.txt
# 玖拾壹萬壹仟陸佰貳拾玖
# 南投	南投_89_訴_382	民事判決	911629	True	[[u'\u5171\u540c\u5f35\u570b\u6968\u5f8b\u5e2b'], 0]
#
# 525 南投_89_訴_403.txt
# 壹佰柒拾萬
# 南投	南投_89_訴_403	民事判決	1700000	True	[0, 0]
#
# 526 南投_89_訴_458.txt
# 南投	南投_89_訴_458	民事判決	0	False	[0, 0]
#
# 527 南投_89_訴_498.txt
# 壹拾萬壹仟壹佰陸拾參
# 南投	南投_89_訴_498	民事判決	101163	True	[0, [u'\u8cf4\u601d\u9054\u5f8b\u5e2b']]
#
# 528 南投_89_訴_507.txt
# 壹拾伍萬參仟柒佰伍拾
# 南投	南投_89_訴_507	民事判決	153750	True	[0, 0]
#
# 529 南投_89_訴_517.txt
# 壹佰伍拾伍萬肆仟陸佰柒拾壹
# 南投	南投_89_訴_517	民事判決	1554671	True	[0, 0]
#
# 530 南投_89_訴_52.txt
# 南投	南投_89_訴_52	民事判決	0	False	[[u'\u5b6b\u660e\u714c\u5f8b\u5e2b', u'\u6797\u842c\u751f\u5f8b\u5e2b'], [u'\u6797\u5764\u8ce2\u5f8b\u5e2b']]
#
# 531 南投_89_訴_539.txt
# 玖萬伍仟肆佰玖拾伍
# 南投	南投_89_訴_539	民事判決	95495	True	[0, 0]
#
# 532 南投_89_訴_548.txt
# 壹拾柒萬參仟柒佰壹拾玖
# 南投	南投_89_訴_548	民事判決	173719	True	[0, 0]
#
# 533 南投_89_訴_567.txt
# 參拾萬
# 南投	南投_89_訴_567	民事判決	300000	True	[0, 0]
#
# 534 南投_89_訴_574.txt
# 貳拾伍萬陸仟捌佰肆拾捌
# 南投	南投_89_訴_574	民事判決	256848	True	[0, 0]
#
# 535 南投_89_訴_58.txt
# 壹佰貳拾萬
# 南投	南投_89_訴_58	民事判決	1200000	True	[0, 0]
#
# 536 南投_89_訴_594.txt
# 伍拾萬
# 南投	南投_89_訴_594	民事判決	500000	True	[0, 0]
#
# 537 南投_89_訴_666.txt
# 伍拾肆萬貳仟陸百陸拾
# 南投	南投_89_訴_666	民事判決	542660	True	[[u'\u694a\u5fd7\u822a\u5f8b\u5e2b'], 0]
#
# 538 南投_89_訴_689.txt
# 柒拾參萬參仟壹佰
# 南投	南投_89_訴_689	民事判決	733100	True	[0, 0]
#
# 539 南投_89_訴_691.txt
# 貳佰貳拾柒萬
# 南投	南投_89_訴_691	民事判決	2270000	True	[0, 0]
#
# 540 南投_89_訴_729.txt
# 南投	南投_89_訴_729	民事判決	0	False	[0, 0]
#
# 541 南投_89_訴_737.txt
# 肆萬貳仟伍佰
# 南投	南投_89_訴_737	民事判決	42500	True	[0, 0]
#
# 542 南投_89_訴_757.txt
# 貳拾肆萬捌仟伍佰零貳
# 南投	南投_89_訴_757	民事判決	248502	True	[0, 0]
#
# 543 南投_89_訴_759.txt
# 貳拾壹萬伍仟壹佰伍拾貳
# 南投	南投_89_訴_759	民事判決	215152	True	[0, 0]
#
# 544 南投_89_訴_764.txt
# 柒拾玖萬陸仟玖佰柒拾肆
# 南投	南投_89_訴_764	民事判決	796974	True	[0, 0]
#
# 545 南投_89_訴_779.txt
# 柒拾柒萬零肆佰玖拾
# 南投	南投_89_訴_779	民事判決	770490	True	[0, 0]
#
# 546 南投_89_訴_789.txt
# 壹佰貳拾萬
# 南投	南投_89_訴_789	民事判決	1200000	True	[0, 0]
#
# 547 南投_89_訴_81.txt
# 肆拾貳萬柒仟壹佰肆拾壹
# 南投	南投_89_訴_81	民事判決	427141	True	[[u'\u8521\u9806\u5c45\u5f8b\u5e2b'], 0]
#
# 548 南投_89_訴_823.txt
# 柒拾貳萬捌仟玖佰柒拾貳
# 南投	南投_89_訴_823	民事判決	728972	True	[0, 0]
#
# 549 南投_89_訴_832.txt
# 貳拾萬
# 南投	南投_89_訴_832	民事判決	200000	True	[[u'\u694a\u7389\u73cd\u5f8b\u5e2b'], 0]
#
# 550 南投_89_訴_85.txt
# 捌拾捌萬玖仟肆佰伍拾肆
# 南投	南投_89_訴_85	民事判決	889454	True	[0, 0]
#
# 551 南投_89_訴更_2.txt
# 南投	南投_89_訴更_2	民事判決	0	False	[0, 0]
#
# 552 南投_89_重訴_140.txt
# 參佰捌拾玖萬貳仟壹佰參拾
# 南投	南投_89_重訴_140	民事判決	3892130	True	[0, 0]
#
# 553 南投_89_重訴_15.txt
# 參仟壹佰參拾伍萬捌仟零玖拾
# 南投	南投_89_重訴_15	民事判決	31358090	True	[0, 0]
#
# 554 南投_89_重訴_16.txt
# 南投	南投_89_重訴_16	民事判決	0	False	[0, 0]
#
# 555 南投_89_重訴_30.txt
# 伍佰參拾壹萬伍仟玖佰柒拾捌
# 南投	南投_89_重訴_30	民事判決	5315978	True	[0, 0]
#
# 556 南投_89_重訴_32.txt
# 伍佰肆拾捌萬伍仟貳佰陸拾伍
# 南投	南投_89_重訴_32	民事判決	5485265	True	[[u'\u5f35\u82f1\u4e00\u5f8b\u5e2b\r'], 0]
#
# 557 南投_89_重訴_61.txt
# 參萬貳仟捌佰玖拾肆
# 南投	南投_89_重訴_61	民事判決	32894	True	[0, 0]
#
# 558 南投_90_埔小_56.txt
# 玖萬零參佰參拾肆
# 南投	南投_90_埔小_56	小額民事判決	90334	True	[0, 0]
#
# 559 南投_90_投簡_460.txt
# 壹拾萬貳仟伍佰柒拾
# 南投	南投_90_投簡_460	民事判決	102570	True	[[u'\u9673\u4e2d\u5805\u5f8b\u5e2b'], [u'\u5f35\u570b\u6968\u5f8b\u5e2b']]
#
# 560 南投_90_訴_102.txt
# 參拾柒萬貳仟玖佰陸拾
# 南投	南投_90_訴_102	民事判決	372960	True	[0, 0]
#
# 561 南投_90_訴_147.txt
# 肆萬柒仟玖佰零陸
# 南投	南投_90_訴_147	民事判決	47906	True	[0, 0]
#
# 562 南投_90_訴_15.txt
# 南投	南投_90_訴_15	民事判決	0	False	[0, 0]
#
# 563 南投_90_訴_155.txt
# 壹拾柒萬柒仟伍佰肆拾捌
# 南投	南投_90_訴_155	民事判決	177548	True	[0, 0]
#
# 564 南投_90_訴_164.txt
# 貳萬零伍拾
# 南投	南投_90_訴_164	民事判決	20050	True	[0, 0]
#
# 565 南投_90_訴_171.txt
# 陸萬肆仟玖佰伍拾
# 南投	南投_90_訴_171	民事判決	64950	True	[0, 0]
#
# 566 南投_90_訴_184.txt
# 柒拾萬貳仟陸佰參拾玖
# ...
#
# 1180 南投_97_訴_346.txt
# 南投	南投_97_訴_346	民事判決	0	False	[0, 0]
#
# 1181 南投_97_訴_364.txt
# 肆拾伍萬零貳佰參拾參
# 南投	南投_97_訴_364	民事判決	450233	True	[0, 0]
#
# 1182 南投_97_訴_407.txt
# 參拾陸萬壹仟捌佰肆拾
# 南投	南投_97_訴_407	民事判決	361840	True	[0, 0]
#
# 1183 南投_97_訴_46.txt
# 壹拾柒萬柒仟肆佰捌拾
# 南投	南投_97_訴_46	民事判決	177480	True	[0, 0]
#
# 1184 南投_97_訴_52.txt
# 玖拾貳萬陸仟柒佰柒拾壹
# 南投	南投_97_訴_52	民事判決	926771	True	[0, 0]
#
# 1185 南投_97_訴_6.txt
# 捌萬
# 南投	南投_97_訴_6	民事判決	80000	True	[0, 0]
#
# 1186 南投_97_訴_76.txt
# 貳拾柒萬
# 南投	南投_97_訴_76	民事判決	270000	True	[0, [u'\u76e7\u6c38\u548c\u5f8b\u5e2b', u'\u8607\u54f2\u79d1\u5f8b\u5e2b']]
#
# 1187 南投_97_訴_79.txt
# 貳佰零捌萬零參佰伍拾陸
# 南投	南投_97_訴_79	民事判決	2080356	True	[[u'\u8521\u5949\u5178\u5f8b\u5e2b'], [u'\u9ec3\u5448\u5229\u5f8b\u5e2b']]
#
# 1188 南投_97_重訴_30.txt
# 柒拾萬參仟伍佰參拾
# 南投	南投_97_重訴_30	民事判決	703530	True	[0, 0]
#
# 1189 南投_97_重訴_40.txt
# 壹佰捌拾柒萬參仟零伍拾玖
# 南投	南投_97_重訴_40	民事判決	1873059	True	[0, 0]
#
# 1190 南投_97_重訴_41.txt
# 貳拾萬壹仟捌佰零貳
# 南投	南投_97_重訴_41	民事判決	201802	True	[0, 0]
#
# 1191 南投_97_重訴_50.txt
# 貳拾肆萬捌仟貳佰壹拾玖
# 南投	南投_97_重訴_50	民事判決	248219	True	[[u'\u9ec3\u6dd1\u771f\u5f8b\u5e2b', u'\u9ec3\u6dd1\u771f\u5f8b\u5e2b'], [u'\u674e\u632f\u7965\u5f8b\u5e2b']]
#
# 1192 南投_98_埔小_167.txt
# 貳萬參仟壹佰貳拾陸
# 南投	南投_98_埔小_167	民事小額判決	23126	True	[0, 0]
#
# 1193 南投_98_埔小_168.txt
# 參萬肆仟捌佰柒拾伍
# 南投	南投_98_埔小_168	民事小額判決	34875	True	[0, 0]
#
# 1194 南投_98_埔小_192.txt
# 肆萬玖仟零捌拾伍
# 南投	南投_98_埔小_192	小額民事判決	49085	True	[0, 0]
#
# 1195 南投_98_埔小_194.txt
# 捌萬捌仟參佰零玖
# 南投	南投_98_埔小_194	民事小額判決	88309	True	[0, 0]
#
# 1196 南投_98_埔小_22.txt
# 南投	南投_98_埔小_22	民事小額判決	0	False	[0, 0]
#
# 1197 南投_98_埔小_26.txt
# 參仟壹佰玖拾貳
# 南投	南投_98_埔小_26	民事小額判決	3192	True	[0, 0]
#
# 1198 南投_98_埔小_88.txt
# 貳萬捌仟參佰肆拾壹
# 南投	南投_98_埔小_88	民事小額判決	28341	True	[0, 0]
#
# 1199 南投_98_埔簡_1.txt
# 柒萬肆仟壹佰伍拾壹
# 南投	南投_98_埔簡_1	民事簡易判決	74151	True	[0, 0]
#
# 1200 南投_98_埔簡_156.txt
# 壹萬零伍佰伍拾
# 南投	南投_98_埔簡_156	民事簡易判決	10550	True	[0, 0]
#
# 1201 南投_98_埔簡_157.txt
# 壹拾壹萬柒仟玖佰零貳
# 南投	南投_98_埔簡_157	民事簡易判決	117902	True	[0, 0]
#
# 1202 南投_98_埔簡_49.txt
# 參萬肆仟零柒拾參
# 南投	南投_98_埔簡_49	民事簡易判決	34073	True	[0, 0]
#
# 1203 南投_98_埔簡_67.txt
# 拾萬捌仟零參拾伍
# 南投	南投_98_埔簡_67	民事簡易判決	108035	True	[0, 0]
#
# 1204 南投_98_埔簡_94.txt
# 肆萬陸仟玖佰玖拾柒
# 南投	南投_98_埔簡_94	民事簡易判決	46997	True	[0, 0]
#
# 1205 南投_98_投小_1.txt
# 貳萬捌仟
# 南投	南投_98_投小_1	小額民事判決	28000	True	[0, 0]
#
# 1206 南投_98_投小_13.txt
# 參萬伍仟捌佰伍拾
# 南投	南投_98_投小_13	民事小額判決	35850	True	[0, 0]
#
# 1207 南投_98_投小_225.txt
# 參萬伍仟陸佰玖拾壹
# 南投	南投_98_投小_225	民事小額判決	35691	True	[0, 0]
#
# 1208 南投_98_投小_246.txt
# 南投	南投_98_投小_246	民事小額判決	0	False	[0, 0]
#
# 1209 南投_98_投小_265.txt
# 捌仟零壹拾
# 南投	南投_98_投小_265	民事小額判決	8010	True	[0, 0]
#
# 1210 南投_98_投小_30.txt
# 貳萬壹仟壹佰零參
# 南投	南投_98_投小_30	民事小額判決	21103	True	[0, 0]
#
# 1211 南投_98_投小_321.txt
# 肆萬玖仟貳佰陸拾參
# 南投	南投_98_投小_321	民事簡易判決	49263	True	[0, 0]
#
# 1212 南投_98_投小_363.txt
# 參萬捌仟伍佰玖拾貳
# 南投	南投_98_投小_363	小額民事判決	38592	True	[0, 0]
#
# 1213 南投_98_投小_411.txt
# 參萬零肆佰捌拾肆
# 南投	南投_98_投小_411	民事小額判決	30484	True	[0, 0]
#
# 1214 南投_98_投小_414.txt
# 新臺幣肆仟捌佰
# 南投	南投_98_投小_414	民事簡易判決	0	True	[0, 0]
#
# 1215 南投_98_投小_417.txt
# 壹萬肆仟陸佰貳拾貳
# 南投	南投_98_投小_417	民事小額判決	14622	True	[0, 0]
#
# 1216 南投_98_投小_426.txt
# 柒仟伍佰肆拾捌
# 南投	南投_98_投小_426	民事簡易判決	7548	True	[0, 0]
#
# 1217 南投_98_投小_446.txt
# 貳萬壹仟陸佰貳拾
# 南投	南投_98_投小_446	民事小額判決	21620	True	[0, 0]
#
# 1218 南投_98_投小_455.txt
# 肆萬參仟參佰陸拾柒
# 南投	南投_98_投小_455	小額民事判決	43367	True	[0, 0]
#
# 1219 南投_98_投小_471.txt
# 肆萬伍仟
# 南投	南投_98_投小_471	民事小額判決	45000	True	[0, 0]
#
# 1220 南投_98_投小_479.txt
# 南投	南投_98_投小_479	民事小額判決	0	False	[0, 0]
#
# 1221 南投_98_投小_493.txt
# 陸仟伍佰
# 南投	南投_98_投小_493	民事小額判決	6500	True	[0, 0]
#
# 1222 南投_98_投小_599.txt
# 南投	南投_98_投小_599	小額民事判決	0	False	[0, 0]
#
# 1223 南投_98_投小_609.txt
# 南投	南投_98_投小_609	民事小額判決	0	False	[0, 0]
#
# 1224 南投_98_投小_617.txt
# 壹萬柒仟玖佰玖拾貳
# 南投	南投_98_投小_617	民事小額判決	17992	True	[0, 0]
#
# 1225 南投_98_投小_98.txt
# 伍萬玖仟伍佰零肆
# 南投	南投_98_投小_98	民事小額判決	59504	True	[0, 0]
#
# 1226 南投_98_投簡_101.txt
# 參萬柒仟玖佰陸拾柒
# 南投	南投_98_投簡_101	民事簡易判決	37967	True	[0, 0]
#
# 1227 南投_98_投簡_129.txt
# 貳拾陸萬柒仟伍佰貳拾
# 南投	南投_98_投簡_129	民事簡易判決	267520	True	[0, 0]
#
# 1228 南投_98_投簡_16.txt
# 壹拾伍萬參仟肆佰捌拾捌
# 南投	南投_98_投簡_16	民事簡易判決	153488	True	[0, 0]
#
# 1229 南投_98_投簡_17.txt
# 柒萬捌仟零柒
# 南投	南投_98_投簡_17	民事簡易判決	78007	True	[0, 0]
#
# 1230 南投_98_投簡_189.txt
# 貳萬伍仟貳佰貳拾玖
# 南投	南投_98_投簡_189	民事簡易判決	25229	True	[0, 0]
#
# 1231 南投_98_投簡_190.txt
# 新臺幣捌萬捌仟壹佰貳拾玖
# 南投	南投_98_投簡_190	民事簡易判決	0	True	[0, 0]
#
# 1232 南投_98_投簡_300.txt
# 新臺幣柒萬柒仟肆佰壹拾參
# 南投	南投_98_投簡_300	民事簡易判決	0	True	[0, 0]
#
# 1233 南投_98_投簡_319.txt
# 壹拾陸萬肆仟捌佰壹拾
# 南投	南投_98_投簡_319	民事簡易判決	164810	True	[0, 0]
#
# 1234 南投_98_投簡_350.txt
# 新臺幣壹拾伍萬
# 南投	南投_98_投簡_350	民事簡易判決	0	True	[0, 0]
#
# 1235 南投_98_投簡_353.txt
# 參拾萬參佰肆拾貳
# 南投	南投_98_投簡_353	民事簡易判決	300342	True	[0, 0]
#
# 1236 南投_98_投簡_375.txt
# 南投	南投_98_投簡_375	民事簡易判決	0	False	[0, 0]
#
# 1237 南投_98_投簡_415.txt
# 陸萬捌仟捌佰肆拾參
# 南投	南投_98_投簡_415	民事簡易判決	68843	True	[0, 0]
#
# 1238 南投_98_投簡_431.txt
# 貳萬
# 南投	南投_98_投簡_431	民事簡易判決	20000	True	[0, 0]
#
# 1239 南投_98_投簡_435.txt
# 參拾參萬壹仟參佰拾伍
# 南投	南投_98_投簡_435	民事簡易判決	331305	True	[0, 0]
#
# 1240 南投_98_投簡_449.txt
# 壹萬柒仟捌佰壹拾貳
# 南投	南投_98_投簡_449	民事簡易判決	17812	True	[0, 0]
#
# 1241 南投_98_投簡_88.txt
# 壹拾柒萬柒仟肆佰參拾
# 南投	南投_98_投簡_88	民事簡易判決	177430	True	[0, 0]
#
# 1242 南投_98_投簡_89.txt
# 壹拾捌萬貳仟陸佰
# 南投	南投_98_投簡_89	民事簡易判決	182600	True	[0, 0]
#
# 1243 南投_98_投簡_91.txt
# 貳拾參萬伍仟伍佰陸拾玖
# 南投	南投_98_投簡_91	民事簡易判決	235569	True	[0, 0]
#
# 1244 南投_98_簡_1.txt
# 貳拾貳萬伍仟陸佰壹拾玖
# 南投	南投_98_簡_1	民事判決	225619	True	[0, 0]
#
# 1245 南投_98_訴_110.txt
# 陸拾貳萬伍仟
# 南投	南投_98_訴_110	民事判決	625000	True	[[u'\u8521\u5fd7\u5fe0\u5f8b\u5e2b'], [u'\u65bd\u88d5\u741b\u5f8b\u5e2b', u'\u65bd\u5b9c\u6615\u5f8b\u5e2b']]
#
# 1246 南投_98_訴_133.txt
# 壹拾陸萬零參佰伍拾肆
# 南投	南投_98_訴_133	民事判決	160354	True	[0, 0]
#
# 1247 南投_98_訴_143.txt
# 壹拾伍萬
# 南投	南投_98_訴_143	民事判決	150000	True	[0, 0]
#
# 1248 南投_98_訴_149.txt
# 肆萬
# 南投	南投_98_訴_149	民事判決	40000	True	[0, 0]
#
# 1249 南投_98_訴_182.txt
# 壹拾貳萬零玖佰
# 南投	南投_98_訴_182	民事判決	120900	True	[0, 0]
#
# 1250 南投_98_訴_189.txt
# 壹佰貳拾伍萬伍仟肆佰玖拾肆
# 南投	南投_98_訴_189	民事判決	1255494	True	[[u'\u5442\u79c0\u6885\u5f8b\u5e2b', u'\u5289\u7469\u73b2\u5f8b\u5e2b'], 0]
#
# 1251 南投_98_訴_195.txt
# 貳拾陸萬陸仟肆佰陸拾貳
# 南投	南投_98_訴_195	民事判決	266462	True	[0, [u'\u6731\u9038\u7fa4\u5f8b\u5e2b']]
#
# 1252 南投_98_訴_250.txt
# 玖拾陸萬貳仟
# 南投	南投_98_訴_250	民事判決	962000	True	[0, 0]
#
# 1253 南投_98_訴_277.txt
# 伍萬
# 南投	南投_98_訴_277	民事判決	50000	True	[[u'\u5f35\u4ed5\u8ce2\u5f8b\u5e2b'], 0]
#
# 1254 南投_98_訴_287.txt
# 伍拾萬壹仟壹佰零肆
# 南投	南投_98_訴_287	民事判決	501104	True	[[u'\u66fe\u742c\u9234\u5f8b\u5e2b'], 0]
#
# 1255 南投_98_訴_290.txt
# 陸拾萬柒仟貳佰陸拾陸
# 南投	南投_98_訴_290	民事判決	607266	True	[0, 0]
#
# 1256 南投_98_訴_292.txt
# 壹拾肆萬壹仟肆佰參拾捌
# 南投	南投_98_訴_292	民事判決	141438	True	[0, 0]
#
# 1257 南投_98_訴_299.txt
# 伍萬
# 南投	南投_98_訴_299	民事判決	50000	True	[0, 0]
#
# 1258 南投_98_訴_307.txt
# 伍拾陸萬柒仟柒佰參拾陸
# 南投	南投_98_訴_307	民事判決	567736	True	[[u'\u5f90\u6587\u5b97\u5f8b\u5e2b'], 0]
#
# 1259 南投_98_訴_351.txt
# 壹佰伍拾貳萬柒仟參佰陸拾參
# 南投	南投_98_訴_351	民事判決	1527363	True	[0, 0]
#
# 1260 南投_98_訴_353.txt
# 南投	南投_98_訴_353	民事判決	0	False	[0, 0]
#
# 1261 南投_98_訴_365.txt
# 參拾貳萬柒仟玖佰玖拾貳
# 南投	南投_98_訴_365	民事判決	327992	True	[[u'\u9ec3\ue4fd\u9234\u5f8b\u5e2b'], 0]
#
# 1262 南投_98_訴_64.txt
# 壹拾萬玖仟壹佰壹拾伍
# 南投	南投_98_訴_64	民事判決	109115	True	[0, 0]
#
# 1263 南投_98_訴_86.txt
# 參拾玖萬陸仟壹佰
# 南投	南投_98_訴_86	民事判決	396100	True	[[u'\u5f35\u5fd7\u9686\u5f8b\u5e2b'], 0]
#
# 1264 南投_98_訴_87.txt
# 伍拾陸萬肆仟玖佰伍拾肆
# 南投	南投_98_訴_87	民事判決	564954	True	[[u'\u5f90\u76db\u570b\u5f8b\u5e2b'], [u'\u738b\u5fe0\u6c82\u5f8b\u5e2b']]
#
# 1265 南投_98_訴_97.txt
# 南投	南投_98_訴_97	民事判決	0	False	[0, 0]
#
# 1266 南投_98_訴_98.txt
# 南投	南投_98_訴_98	民事判決	0	False	[0, [u'\u9ec3\u632f\u6e90\u5f8b\u5e2b', u'\u8521\u9806\u5c45\u5f8b\u5e2b']]
#
# 1267 南投_98_醫_1.txt
# 南投	南投_98_醫_1	民事判決	0	False	[0, [u'\u9673\u93ae\u5f8b\u5e2b\r', u'\u674e\u6dd1\u5a1f\u5f8b\u5e2b']]
#
# 1268 南投_98_重訴_11.txt
# 壹拾伍萬
# 南投	南投_98_重訴_11	民事判決	150000	True	[0, 0]
#
# 1269 南投_98_重訴_14.txt
# 伍佰陸拾柒萬貳仟捌佰玖拾玖
# 南投	南投_98_重訴_14	民事判決	5672899	True	[0, 0]
#
# 1270 南投_98_重訴_17.txt
# 南投	南投_98_重訴_17	民事判決	0	False	[[u'\u6797\u66f4\u7950\u5f8b\u5e2b', u'\u6797\u842c\u751f\u5f8b\u5e2b\r', u'\u8cf4\u9326\u6e90\u5f8b\u5e2b', u'\u6797\u66f4\u7950\u5f8b\u5e2b', u'\u6797\u842c\u751f\u5f8b\u5e2b\r', u'\u8cf4\u9326\u6e90\u5f8b\u5e2b', u'\u6797\u66f4\u7950\u5f8b\u5e2b', u'\u6797\u842c\u751f\u5f8b\u5e2b\r', u'\u8cf4\u9326\u6e90\u5f8b\u5e2b'], [u'\u7f85\u8c50\u80e4\u5f8b\u5e2b', u'\u8521\u7d20\u60e0\u5f8b\u5e2b\r']]
#
# 1271 南投_98_重訴_25.txt
# 參佰肆拾肆萬貳仟伍佰貳拾捌
# 南投	南投_98_重訴_25	民事判決	3442528	True	[0, 0]
#
# 1272 南投_98_重訴_31.txt
# 壹仟參佰參拾參萬肆仟肆佰參拾壹
# 南投	南投_98_重訴_31	民事判決	13334431	True	[[u'\u694a\u4fca\u5f65\u5f8b\u5e2b', u'\u6d2a\u5d07\u6b3d\u5f8b\u5e2b'], 0]
#
# 1273 南投_98_重訴_32.txt
# 捌拾參萬伍仟捌佰參拾壹
# 南投	南投_98_重訴_32	民事判決	835831	True	[0, [u'\u5f35\u7e7c\u6e96\u5f8b\u5e2b', u'\u8607\u82e5\u9f8d\u5f8b\u5e2b', u'\u838a\u60e0\u797a\u5f8b\u5e2b']]
#
# 1274 南投_98_重訴_38.txt
# 壹佰伍拾陸萬肆仟捌佰玖拾柒
# 南投	南投_98_重訴_38	民事判決	1564897	True	[0, 0]
#
# 1275 南投_98_重訴_4.txt
# 玖拾捌萬捌仟陸佰零參
# 南投	南投_98_重訴_4	民事判決	988603	True	[0, 0]
#
# 1276 南投_98_重訴_45.txt
# 陸拾陸萬陸仟陸佰陸拾貳
# 南投	南投_98_重訴_45	民事判決	666662	True	[0, 0]
#
# 1277 南投_98_重訴_5.txt
# 壹佰柒拾肆萬陸仟陸佰捌拾參
# 南投	南投_98_重訴_5	民事判決	1746683	True	[[u'\u738b\u5ead\u9d3b\u5f8b\u5e2b'], [u'\u6797\u958b\u798f\u5f8b\u5e2b', u'\u8463\u6021\u541b\u5f8b\u5e2b\r']]
#
# 1278 南投_99_埔小_121.txt
# 貳萬參仟陸佰零捌
# 南投	南投_99_埔小_121	民事小額判決	23608	True	[0, 0]
#
# 1279 南投_99_埔小_153.txt
# 壹萬壹仟伍佰玖拾捌
# 南投	南投_99_埔小_153	民事小額判決	11598	True	[0, 0]
#
# 1280 南投_99_埔小_171.txt
# 肆萬肆仟捌佰捌拾肆
# 南投	南投_99_埔小_171	民事小額判決	44884	True	[0, 0]
#
# 1281 南投_99_埔小_21.txt
# 伍仟肆佰拾壹
# 南投	南投_99_埔小_21	民事小額判決	5401	True	[0, 0]
#
# 1282 南投_99_埔小_72.txt
# 陸仟
# 南投	南投_99_埔小_72	民事簡易判決	6000	True	[0, 0]
#
# 1283 南投_99_埔小_78.txt
# 壹萬陸仟捌佰
# 南投	南投_99_埔小_78	民事小額判決	16800	True	[0, 0]
#
# 1284 南投_99_埔小_84.txt
# 玖萬伍仟陸佰貳拾捌
# 南投	南投_99_埔小_84	民事小額判決	95628	True	[0, 0]
#
# 1285 南投_99_埔小_92.txt
# 伍萬參仟貳佰捌拾伍
# 南投	南投_99_埔小_92	民事小額判決	53285	True	[0, 0]
#
# 1286 南投_99_埔簡_152.txt
# 貳萬零伍佰伍拾
# 南投	南投_99_埔簡_152	民事簡易判決	20550	True	[0, 0]
#
# 1287 南投_99_埔簡_26.txt
# 壹拾玖萬玖仟陸佰壹拾貳
# 南投	南投_99_埔簡_26	民事簡易判決	199612	True	[0, 0]
#
# 1288 南投_99_埔簡_44.txt
# 玖萬
# 南投	南投_99_埔簡_44	民事簡易判決	90000	True	[0, 0]
#
# 1289 南投_99_埔簡_6.txt
# 陸佰陸拾伍
# 南投	南投_99_埔簡_6	民事簡易判決	665	True	[0, 0]
#
# 1290 南投_99_投小_13.txt
# 參萬陸仟捌佰柒拾參
# 南投	南投_99_投小_13	民事小額判決	36873	True	[0, 0]
#
# 1291 南投_99_投小_150.txt
# 肆萬肆仟肆佰柒拾柒
# 南投	南投_99_投小_150	民事小額判決	44477	True	[[u'\u9673\u76ca\u8ed2\u5f8b\u5e2b'], 0]
#
# 1292 南投_99_投小_166.txt
# 參萬貳仟貳佰伍拾柒
# 南投	南投_99_投小_166	民事小額判決	32257	True	[0, 0]
#
# 1293 南投_99_投小_176.txt
# 參萬玖仟玖佰陸拾
# 南投	南投_99_投小_176	民事小額判決	39960	True	[0, 0]
#
# 1294 南投_99_投小_210.txt
# 肆萬柒仟伍佰柒拾
# 南投	南投_99_投小_210	民事小額判決	47570	True	[0, 0]
#
# 1295 南投_99_投小_214.txt
# 壹萬伍仟柒佰伍拾參
# 南投	南投_99_投小_214	民事小額判決	15753	True	[0, 0]
#
# 1296 南投_99_投小_22.txt
# 壹萬貳仟參佰肆拾柒
# 南投	南投_99_投小_22	民事小額判決	12347	True	[0, 0]
#
# 1297 南投_99_投小_226.txt
# 貳萬捌仟玖佰零陸
# 南投	南投_99_投小_226	民事小額判決	28906	True	[0, 0]
#
# 1298 南投_99_投小_233.txt
# 柒萬貳仟壹佰陸拾
# 南投	南投_99_投小_233	小額民事判決	72160	True	[0, 0]
#
# 1299 南投_99_投小_238.txt
# 南投	南投_99_投小_238	民事小額判決	0	False	[0, 0]
#
# 1300 南投_99_投小_28.txt
# 肆仟陸佰捌拾貳
# 南投	南投_99_投小_28	小額民事判決	4682	True	[0, 0]
#
# 1301 南投_99_投小_33.txt
# 伍仟柒佰伍拾貳
# 南投	南投_99_投小_33	民事小額判決	5752	True	[0, 0]
#
# 1302 南投_99_投小_350.txt
# 捌仟壹佰伍拾
# 南投	南投_99_投小_350	民事小額判決	8150	True	[0, 0]
#
# 1303 南投_99_投小_354.txt
# 參萬
# 南投	南投_99_投小_354	民事小額判決	30000	True	[0, 0]
#
# 1304 南投_99_投小_388.txt
# 壹萬
# 南投	南投_99_投小_388	民事小額判決	10000	True	[0, 0]
#
# 1305 南投_99_投小_401.txt
#
# 南投	南投_99_投小_401	民事小額判決	0	True	[0, 0]
#
# 1306 南投_99_投小_406.txt
# 參萬伍仟柒佰
# 南投	南投_99_投小_406	民事小額判決	35700	True	[0, 0]
#
# 1307 南投_99_投小_429.txt
# 伍萬參仟零貳
# 南投	南投_99_投小_429	民事小額判決	53002	True	[0, 0]
#
# 1308 南投_99_投小_43.txt
# 壹萬捌仟伍佰零壹
# 南投	南投_99_投小_43	民事小額判決	18501	True	[0, 0]
#
# 1309 南投_99_投小_55.txt
# 捌仟肆佰
# 南投	南投_99_投小_55	民事小額判決	8400	True	[0, 0]
#
# 1310 南投_99_投簡_101.txt
# 參萬參仟捌佰參拾肆
# 南投	南投_99_投簡_101	民事簡易判決	33834	True	[0, 0]
#
# 1311 南投_99_投簡_102.txt
# 壹拾貳萬柒仟壹佰柒拾
# 南投	南投_99_投簡_102	民事簡易判決	127170	True	[0, 0]
#
# 1312 南投_99_投簡_118.txt
# 新臺幣柒萬陸仟玖佰捌拾肆
# 南投	南投_99_投簡_118	民事簡易判決	0	True	[0, 0]
#
# 1313 南投_99_投簡_142.txt
# 貳萬肆仟參佰陸拾肆
# 南投	南投_99_投簡_142	民事簡易判決	24364	True	[0, 0]
#
# 1314 南投_99_投簡_150.txt
# 參萬壹仟玖佰伍拾
# 南投	南投_99_投簡_150	民事簡易判決	31950	True	[0, 0]
#
# 1315 南投_99_投簡_151.txt
# 伍萬捌仟
# 南投	南投_99_投簡_151	民事簡易判決	58000	True	[0, 0]
#
# 1316 南投_99_投簡_156.txt
# 壹拾伍萬
# 南投	南投_99_投簡_156	民事簡易判決	150000	True	[0, [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b']]
#
# 1317 南投_99_投簡_161.txt
# 肆萬零捌佰柒拾柒
# 南投	南投_99_投簡_161	民事簡易判決	40877	True	[0, 0]
#
# 1318 南投_99_投簡_208.txt
# 肆萬伍仟貳佰參拾玖
# 南投	南投_99_投簡_208	民事簡易判決	45239	True	[0, 0]
#
# 1319 南投_99_投簡_3.txt
# 新臺幣捌萬肆仟參佰玖拾貳
# 南投	南投_99_投簡_3	民事簡易判決	0	True	[0, [u'\u674e\u660e\u6d77\u5f8b\u5e2b']]
#
# 1320 南投_99_投簡_316.txt
# 壹拾萬肆仟零壹拾
# 南投	南投_99_投簡_316	民事簡易判決	104010	True	[0, 0]
#
# 1321 南投_99_投簡_323.txt
# 貳拾參萬柒仟壹佰捌拾
# 南投	南投_99_投簡_323	民事簡易判決	237180	True	[0, 0]
#
# 1322 南投_99_投簡_349.txt
# 南投	南投_99_投簡_349	民事簡易判決	0	False	[0, 0]
#
# 1323 南投_99_投簡_38.txt
# 參萬壹仟肆佰
# 南投	南投_99_投簡_38	民事簡易判決	31400	True	[0, 0]
#
# 1324 南投_99_投簡_50.txt
# 壹拾肆萬貳仟伍佰貳拾伍
# 南投	南投_99_投簡_50	民事簡易判決	142525	True	[0, 0]
#
# 1325 南投_99_投簡_76.txt
# 壹拾參萬壹仟捌佰零壹
# 南投	南投_99_投簡_76	民事簡易判決	131801	True	[0, 0]
#
# 1326 南投_99_簡_1.txt
# 伍萬
# 南投	南投_99_簡_1	民事判決	50000	True	[0, 0]
#
# 1327 南投_99_訴_105.txt
# 參萬
# 南投	南投_99_訴_105	民事判決	30000	True	[0, 0]
#
# 1328 南投_99_訴_118.txt
# 壹拾萬
# 南投	南投_99_訴_118	民事判決	100000	True	[[u'\u8a31\u667a\u6377\u5f8b\u5e2b'], 0]
#
# 1329 南投_99_訴_136.txt
# 貳拾萬
# 南投	南投_99_訴_136	民事判決	200000	True	[0, 0]
#
# 1330 南投_99_訴_137.txt
# 南投	南投_99_訴_137	民事判決	0	False	[[u'\u8cf4\u9326\u6e90\u5f8b\u5e2b', u'\u6797\u842c\u751f\u5f8b\u5e2b'], [u'\u7f85\u8c50\u80e4\u5f8b\u5e2b', u'\u9ec3\u9756\u9594\u5f8b\u5e2b']]
#
# 1331 南投_99_訴_18.txt
# 陸拾柒萬貳仟壹佰壹拾壹
# 南投	南投_99_訴_18	民事判決	672111	True	[[u'\u694a\u5fd7\u822a\u5f8b\u5e2b'], 0]
#
# 1332 南投_99_訴_181.txt
# 肆拾伍萬
# 南投	南投_99_訴_181	民事判決	450000	True	[0, 0]
#
# 1333 南投_99_訴_24.txt
# 貳佰玖拾萬捌仟零伍拾伍
# 南投	南投_99_訴_24	民事判決	2908055	True	[[u'\u674e\u660e\u6d77\u5f8b\u5e2b', u'\u8a79\u5fd7\u5b8f\u5f8b\u5e2b', u'\u694a\u5b9b\u745c\u5f8b\u5e2b\r'], [u'\u5442\u79c0\u6885\u5f8b\u5e2b']]
#
# 1334 南投_99_訴_242.txt
# 肆萬零捌佰肆拾貳
# 南投	南投_99_訴_242	民事判決	40842	True	[0, [u'\u5f90\u66c9\u840d\u5f8b\u5e2b']]
#
# 1335 南投_99_訴_257.txt
# 壹佰伍拾貳萬零貳佰肆拾捌
# 南投	南投_99_訴_257	民事判決	1520248	True	[0, 0]
#
# 1336 南投_99_訴_268.txt
# 南投	南投_99_訴_268	民事判決	0	False	[0, 0]
#
# 1337 南投_99_訴_282.txt
# 壹佰伍拾萬及自民國九十九年十月二十六日起至清償日止，按週年利率百分之五計算之利息。訴訟費用新臺幣壹萬伍仟捌佰伍拾
# 南投	南投_99_訴_282	民事判決	1500000	True	[0, 0]
#
# 1338 南投_99_訴_291.txt
# 南投	南投_99_訴_291	民事判決	0	False	[[u'\u5f35\u7e7c\u6e96\u5f8b\u5e2b', u'\u8607\u82e5\u9f8d\u5f8b\u5e2b', u'\u838a\u60e0\u797a\u5f8b\u5e2b\r'], 0]
#
# 1339 南投_99_訴_300.txt
# 壹佰零玖萬零壹佰伍拾肆
# 南投	南投_99_訴_300	民事判決	1090154	True	[[u'\u6797\u76ca\u8f1d\u5f8b\u5e2b'], [u'\u6c5f\u4f86\u76db\u5f8b\u5e2b']]
#
# 1340 南投_99_訴_331.txt
# 南投	南投_99_訴_331	民事判決	0	False	[[u'\u66fe\u4fe1\u5609\u5f8b\u5e2b'], [u'\u9673\u80d8\u5bcc\u5f8b\u5e2b']]
#
# 1341 南投_99_訴_42.txt
# 壹佰柒拾壹萬壹仟壹佰捌拾壹
# 南投	南投_99_訴_42	民事判決	1711181	True	[[u'\u9673\u4fee\u4ec1\u5f8b\u5e2b'], 0]
#
# 1342 南投_99_訴_50.txt
# 柒萬
# 南投	南投_99_訴_50	民事判決	70000	True	[0, 0]
#
# 1343 南投_99_訴_55.txt
# 壹佰柒拾壹萬柒仟貳佰伍拾
# 南投	南投_99_訴_55	民事判決	1717250	True	[0, 0]
#
# 1344 南投_99_訴_63.txt
# 伍拾壹萬貳仟壹佰肆拾壹
# 南投	南投_99_訴_63	民事判決	512141	True	[0, 0]
#
# 1345 南投_99_訴_64.txt
# 南投	南投_99_訴_64	民事判決	0	False	[0, 0]
#
# 1346 南投_99_訴_72.txt
# 貳佰陸拾伍萬捌仟肆佰柒拾肆
# 南投	南投_99_訴_72	民事判決	2658474	True	[[u'\u9673\u4fee\u4ec1\u5f8b\u5e2b'], [u'\u5433\u842c\u6625\u5f8b\u5e2b']]
#
# 1347 南投_99_訴_8.txt
# 肆萬壹仟參佰陸拾陸
# 南投	南投_99_訴_8	民事判決	41366	True	[0, 0]
#
# 1348 南投_99_訴_89.txt
# 壹佰伍拾萬
# 南投	南投_99_訴_89	民事判決	1500000	True	[0, 0]
#
# 1349 南投_99_醫_3.txt
# 南投	南投_99_醫_3	民事判決	0	False	[[u'\u80e1\u5b97\u667a\u5f8b\u5e2b'], [u'\u9673\u570b\u83ef\u5f8b\u5e2b']]
#
# 1350 南投_99_醫_4.txt
# 捌拾壹萬壹仟參佰捌拾肆
# 南投	南投_99_醫_4	民事判決	811384	True	[[u'\u5f35\u5fd7\u9686\u5f8b\u5e2b'], [u'\u9ec3\u6e05\u6ff1\u5f8b\u5e2b', u'\u5442\u8d85\u7fa4\u5f8b\u5e2b']]
#
# 1351 南投_99_醫_5.txt
# 南投	南投_99_醫_5	民事判決	0	False	[0, [u'\u9ec3\u6e05\u6ff1\u5f8b\u5e2b']]
#
# 1352 南投_99_重訴_10.txt
# 壹佰參拾萬零柒佰貳拾玖
# 南投	南投_99_重訴_10	民事判決	1300729	True	[0, [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b']]
#
# 1353 南投_99_重訴_12.txt
# 貳仟肆佰陸拾參萬零肆佰玖拾貳
# 南投	南投_99_重訴_12	民事判決	24630492	True	[[u'\u8d99\u5efa\u8208\u5f8b\u5e2b'], [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b']]
#
# 1354 南投_99_重訴_17.txt
# 陸拾參萬伍仟壹佰參拾
# 南投	南投_99_重訴_17	民事判決	635130	True	[[u'\u7518\u9f8d\u5f37\u5f8b\u5e2b'], 0]
#
# 1355 南投_99_重訴_20.txt
# 伍拾伍萬捌仟壹佰捌拾參
# 南投	南投_99_重訴_20	民事判決	558183	True	[[u'\u5f90\u6587\u5b97\u5f8b\u5e2b'], 0]
#
# 1356 南投_99_重訴_25.txt
# 壹佰壹拾柒萬柒仟貳佰零玖
# 南投	南投_99_重訴_25	民事判決	1177209	True	[[u'\u6c5f\u5f57\u9234\u5f8b\u5e2b'], [u'\u694a\u7389\u73cd\u5f8b\u5e2b', u'\u5ed6\u5091\u9a4a\u5f8b\u5e2b']]
#
# 1357 南投_99_重訴_3.txt
# 陸拾伍萬玖仟玖佰肆拾參
# 南投	南投_99_重訴_3	民事判決	659943	True	[[u'\u66fe\u742c\u9234\u5f8b\u5e2b'], 0]
#
# 1358 南投_99_重訴_31.txt
# 捌萬伍仟貳佰捌拾
# 南投	南投_99_重訴_31	民事判決	85280	True	[[u'\u9ec3\ue4fd\u9234\u5f8b\u5e2b'], 0]
#
# 1359 南投_99_重訴_39.txt
# 貳佰柒拾玖萬貳仟壹佰陸拾柒
# 南投	南投_99_重訴_39	民事判決	2792167	True	[[u'\u9673\u660e\u767c\u5f8b\u5e2b', u'\u5433\u842c\u6625\u5f8b\u5e2b'], 0]
#
# 1360 南投_99_重訴_5.txt
# 壹佰貳拾伍萬捌佰參拾壹
# 南投	南投_99_重訴_5	民事判決	1250831	True	[[u'\u8a31\u5bb6\u745c\u5f8b\u5e2b', u'\u4e59\u25cb\u25cb\u5f8b\u5e2b'], 0]
#
# 1361 南投_99_重訴_8.txt
# 肆佰肆拾伍萬捌仟貳佰伍拾捌
# 南投	南投_99_重訴_8	民事判決	4458258	True	[[u'\u9ec3\ue4fd\u9234\u5f8b\u5e2b'], [u'\u5f35\u667a\u7fd4\u5f8b\u5e2b', u'\u9ec3\u9f0e\u921e\u5f8b\u5e2b', u'\u9673\u9298\u5091\u5f8b\u5e2b']]
#
# 1362 南投_99_重訴更_1.txt
# 南投	南投_99_重訴更_1	民事判決	0	False	[[u'\u8d99\u5efa\u8208\u5f8b\u5e2b'], [u'\u5f35\u82f1\u4e00\u5f8b\u5e2b']]
#
# done

# %%
transform(u'參萬參仟零壹拾陸')
# Out:
# 參萬參仟零壹拾陸
# 33016
