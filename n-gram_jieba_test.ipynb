	高雄簡易庭法官林記弘\
	以上正本係照原本作成。\
	如不服本判決，應於送達後20日內，向本院提出上訴狀並表明上訴理由，如於本判決宣示後送達前提起上訴者，應於判決送達後20日內補提上訴理由書（須附繕本）。\
	中華民國104年4月10日\
	書記官王壹理\
	訴訟費用計算式：\
	裁判費（新臺幣）1,880元\
	合計1,880元\
'
for word in ngram(''.join(text.split()), 1):
    print word,
# Out:
# 、 讀 閃 清 的 與 來 下 越 損 二 意 椎 抑 制 醒 路 識 力 級 撞 管 1 淚 邊 大 天 用 被 佳 擊 就 3 嘴 斷 父 7 頸 去 為 看 全 流 無 黃 上 雄 強 應 母 吸 車 前 每 ， 插 眨 摔 受 他 雙 高 線 針 效 盡 因 以 師 跨 顯 眼 癱 陳 年 部 後 學 電 醫 都 呼 避

# %%
import re
delimiter = "，|。|、"  
text = '3年前就讀高雄應用大學二年級的陳顯佳，為閃避跨越雙黃線來車，撞上路邊、摔斷頸椎，頸部以下全癱，嘴被插管，父母每天去看他，他都意識清醒、眨眼流淚，17天後他因頸椎受損抑制呼吸，醫師用盡強力針與電擊都無效，'
for i in re.split(delimiter, ''.join(text.strip().split())):
    print i
# Out:
# 3年前就讀高雄應用大學二年級的陳顯佳
# 為閃避跨越雙黃線來車
# 撞上路邊
# 摔斷頸椎
# 頸部以下全癱
# 嘴被插管
# 父母每天去看他
# 他都意識清醒
# 眨眼流淚
# 17天後他因頸椎受損抑制呼吸
# 醫師用盡強力針與電擊都無效

# %%
import re
delimiter = "，|。|、"
# fname = <filename>.decode('utf-8')
# f = open(fname, 'r')
# text = f.read()
# f.close
newtext = ''.join(text1.split())
newtext = ''.join(newtext.split("　"))
newtext = ''.join(newtext.split(","))
for i in re.split(delimiter, ''.join(newtext)):
    if '原告' in i:
        print i
# Out:
# 【裁判字號】103雄簡1979【裁判日期】1040410【裁判案由】損害賠償【裁判全文】臺灣高雄地方法院民事判決103年度雄簡字第1979號原告李胡秀枝訴訟代理人洪錦財李麗娟被告曾重榮上列當事人間請求損害賠償事件
# 判決如下：主文被告應給付原告新臺幣玖萬柒仟柒佰捌拾肆元
# 原告其餘之訴駁回
# 餘由原告負擔
# 本判決原告勝訴部分得假執行
# 爰依原告聲請
# 原告不得將原訴變更或追加他訴
# 查原告起訴原請求被告給付原告新臺幣（下同）180000元
# 嗣於本院審理中減縮請求被告給付原告130177元
# 原告主張：被告於民國102年5月8日駕駛車牌號碼00-0000號自用小貨車在高雄市三民區市中一路涵洞下旁開啟車門之際
# 致原告騎乘腳踏車閃避不及發生車禍
# 造成原告右手4
# 並聲明：被告應給付原告130177元
# 本件原告主張被告於上開時
# 致原告受有上開傷害等情
# 視同對原告主張之事實為自認
# 堪信原告主張為真實
# 則被告因過失不法侵害原告之身體權
# 自應對原告負過失侵權行為損害賠償責任
# 茲就原告請求被告賠償之金額是否應予准許
# 原告主張因本件車禍受傷
# 原告前已用於請領強制汽車責任保險理賠金
# 並經富邦產物保險股份有限公司理賠11681元予原告
# 原告得請求被告賠償之醫療費用金額應為9784元【計算式：21465元－11681元＝9784元】
# 本院審酌原告之傷勢及就診之內容
# 認原告至上揭醫療院所就診支出之費用應屬必要
# 原告請求被告給付上揭醫療費用9784元乙情
# (二)交通費用部分：原告主張因本件車禍受傷
# 足信原告因車禍受傷後
# 是原告此部分之請求
# 查原告因被告之侵權行為而受有上開身體上之傷害
# 本院審酌原告名下所得共4筆
# 兼考量原告所受損害程度
# 認原告請求100712元之慰撫金
# 原告依據侵權行為之法律關係
# 本判決原告勝訴部分係依民事訴訟法第427條第1項所規定之適用簡易訴訟程序所為被告敗訴之判決

# %%
import jieba
newtext = ''.join(text.split(','))
words = jieba.cut(newtext, cut_all=False)
for word in words:
    print word
# Out:
# Building prefix dict from C:\Python27\lib\site-packages\jieba\dict.txt ...
# DEBUG:jieba:Building prefix dict from C:\Python27\lib\site-packages\jieba\dict.txt ...
# Loading model from cache c:\users\hsiao\appdata\local\temp\jieba.cache
# DEBUG:jieba:Loading model from cache c:\users\hsiao\appdata\local\temp\jieba.cache
# Loading model cost 0.524000167847 seconds.
# DEBUG:jieba:Loading model cost 0.524000167847 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# 3
# 年前
# 就
# 讀
# 高雄
# 應用
# 大學
# 二年
# 級
# 的
# 陳
# 顯佳
# ，
# 為
# 閃避
# 跨越
# 雙黃線
# 來車
# ，
# 撞
# 上路
# 邊
# 、
# 摔斷
# 頸
# 椎
# ，
# 頸部
# 以下
# 全癱
# ，
# 嘴
# 被
# 插管
# ，
# 父母
# 每天
# 去
# 看
# 他
# ，
# 他
# 都
# 意識
# 清醒
# 、
# 眨眼
# 流淚
# ，
# 17
# 天後他
# 因頸椎
# 受損
# 抑制
# 呼吸
# ，
# 醫師用
# 盡強
# 力針
# 與
# 電擊
# 都
# 無效
# ，

# %%
import jieba
import jieba.analyse

sentence = u"談大數據分析之前，最重要的是學習如何蒐集數據；但數據該如何蒐集呢？如果能將浩瀚的網路資源都變成自家的資料庫，是不是就不用擔憂資料的來源了。本實戰課程系列將教會您如何撰寫簡單的爬蟲幫您快速蒐集開放資料，開始大數據分析的第一步！"

#jieba.analyse.set_stop_words('StopTest.txt')
tags = jieba.analyse.extract_tags(sentence, 10)

words = jieba.cut(sentence, cut_all=False)
#for word in words:
#    print word

print "Output："
print ",".join(tags)
# Out:
# Output：
# 資料,如何,來源,變成,將教會,本實戰,課程,開始,能將,學習

# %%
import jieba
import jieba.analyse

sentence = u"談大數據分析之前，最重要的是學習如何蒐集數據；但數據該如何蒐集呢？如果能將浩瀚的網路資源都變成自家的資料庫，是不是就不用擔憂資料的來源了。本實戰課程系列將教會您如何撰寫簡單的爬蟲幫您快速蒐集開放資料，開始大數據分析的第一步！"

#jieba.analyse.set_stop_words('StopTest.txt')
#tags = jieba.analyse.extract_tags(sentence, 15)

words = jieba.cut(sentence, cut_all=False)
for word in words:
    if word not in [u'數據']:
        print word

# print "Output："
# print ",".join(tags)

# for term in tags:
#     if term not in [u'資料']:
#         print term,
